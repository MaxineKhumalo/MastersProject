# %% [markdown]
# # QAOA gridsearch

# %%
#Initialisation cell
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

from docplex.mp.model import Model
from qiskit.providers.ibmq.managed import IBMQJobManager

from qiskit import BasicAer, Aer
from qiskit.aqua.algorithms import VQE, ExactEigensolver,NumPyEigensolver,QAOA
from qiskit.aqua.components.optimizers import SPSA, COBYLA,ADAM, L_BFGS_B
from qiskit.circuit.library import RealAmplitudes #(uses CX entangling) 
from qiskit.optimization.applications.ising.common import sample_most_likely
from qiskit.circuit.library import TwoLocal
#from qiskit.aqua.components.variational_forms import RY
from qiskit.aqua import QuantumInstance

from qiskit.optimization import QuadraticProgram
from qiskit.tools.visualization import plot_histogram
from qiskit.optimization.applications.ising import docplex
from qiskit.optimization.algorithms import MinimumEigenOptimizer,RecursiveMinimumEigenOptimizer

# setup aqua logging
import logging
from qiskit.aqua import set_qiskit_aqua_logging
# set_qiskit_aqua_logging(logging.DEBUG)  # choose INFO, DEBUG to see the log

# useful additional packages 
import matplotlib.pyplot as plt
import matplotlib.axes as axes
# %matplotlib inline
import numpy as np
import networkx as nx
import pandas as pd
from   matplotlib import cm
from   matplotlib.ticker import LinearLocator, FormatStrFormatter
# %config InlineBackend.figure_format = 'svg' # Makes the images look nice

# importing Qiskit
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, execute
from qiskit.providers.ibmq      import least_busy
from qiskit.tools.monitor       import job_monitor
from qiskit.providers.aer import QasmSimulator

# %% [markdown]
# Important prelim functions

# %%
def CSVtoNumpyArray(rawdata):
    """
    Input: 
    rawdata = a csv file (insert name as a string)

    Output:
    two numpy matrices in a tuple
    """
    data = pd.read_csv(rawdata)  #Reads the data in as a pandas object
    c = data.columns
    column = int(c[0])
    final_data1 = data.iloc[:column,:].values  #Sets data into a series of numpy arrays of strings
    final_data2 = data.iloc[column:,:].values  #1 is for the first matrix(loc) and 2 is for the second(flow)
    

    #Forms the matrix as a numpy array (easier to work with) instead of an list of lists of strings
    def string_to_integers(final_data):
        matrix = []
        for j in range(column):
            string = final_data[j][0]
            string2 = string.split(" ")
            emptyarray = []
            for i in string2:
                if i != '':
                    emptyarray.append(int(i))
            matrix.append(emptyarray)
        npmatrix = np.array(matrix) 
        return npmatrix
    return string_to_integers(final_data1),string_to_integers(final_data2)

# %%
def qap_value(z, MatrixLoc, MatrixFlow):
    """Compute the TSP value of a solution.
    Args:
        z (list[int]): list of allocations
        MatrixLoc (numpy array): matrix of distances
        MatrixFlow (numpy array): matrix of flow
    Returns:
        float: value of the QAP
    """
    matrix_length = len(MatrixLoc)
    x = np.reshape(z, (matrix_length,matrix_length))
    
    total = 0
    for i in range(matrix_length):
        for j in range(matrix_length):
            for k in range(matrix_length):
                for p in range(matrix_length):
                        total += MatrixLoc[i,j]* MatrixFlow[k,p]*x[i,k]*x[j,p]
    
    return total

# %% [markdown]
# Feasibility functions

# %%
def qap_feasible(x):
    """Check whether a solution is feasible or not.

    Args:
        x (numpy.ndarray) : binary string as numpy array.

    Returns:
        bool: feasible or not.
    """
    n = int(np.sqrt(len(x)))
    y = np.reshape(x, (n,n))
   
    for i in range(n):
        if sum(y[i, p] for p in range(n)) != 1:
            return False
    for p__ in range(n):
        if sum(y[i, p__] for i in range(n)) != 1:
            return False
    return True

# %%
def choose_best_feasible(eigenstates):
    """
    Input:
    eigenstates = dictionary
    
    Output:
    feasible binary 1D numpyarray
    probability of this answer
    
    """
    bestinarray = sorted(eigenstates.items(), key=lambda item: item[1])[::-1]
    feasible = False
    counter = 0
    total = sum(eigenstates.values())
    
    feasible=False
    while feasible==False and counter<len(bestinarray):
        #string to array
        bestasint = np.array([0])
        for i in bestinarray[counter][0]:
            bestasint = np.hstack((bestasint, int(i)))
        feasible = qap_feasible(bestasint[1:])
        frequency = bestinarray[counter][1]
        counter += 1
        
    if feasible == False:
        return feasible
    else:
        return bestasint[1:], frequency/total

# %% [markdown]
# ## The QAOA function

# %%
def testing_quantum(ins, start, stop, step):
    """
    Input:
    ins: name of instance
    start
    stop
    step
    
    Output:
    outmatrix : [soln,result time,eigenvector,number of spsa trials]
    """
    
    #get matrix
    datamatrix = CSVtoNumpyArray(ins)
    MatrixLoc = datamatrix[0]
    MatrixFlow = datamatrix[1]
    n = len(MatrixLoc)

    # Create an instance of a model and variables.
    thename = "qap" + str(n)
    mdl = Model(name=thename)
    x = {(i,p): mdl.binary_var(name='x_{0}_{1}'.format(i,p)) for i in range(n) for p in range(n)}

    # Object function
    qap_func = mdl.sum(MatrixLoc[i,j]* MatrixFlow[k,p]*x[i,k]*x[j,p] for i in range(n) for j in range(n) for p in range(n) for k in range(n))
    mdl.minimize(qap_func)

    # Constraints
    for i in range(n):
        mdl.add_constraint(mdl.sum(x[(i,p)] for p in range(n)) == 1)
    for p in range(n):
        mdl.add_constraint(mdl.sum(x[(i,p)] for i in range(n)) == 1)
    print(mdl.export_to_string())
    qubitOp_docplex, offset_docplex = docplex.get_operator(mdl) #potential error

    #QAOA
    machinesolutions = []
    rmachinesolutions = []
    seed = 10598
    mod = QuadraticProgram()
    mod.from_docplex(mdl)
    #print(mod.export_as_lp_string())

    for i in range(start,stop,step):
        spsa = SPSA(maxiter=i)
        backend = Aer.get_backend('qasm_simulator')
        backend.set_options(method= "matrix_product_state")
        quantum_instance = QuantumInstance(backend=backend,seed_simulator=seed,
                                           seed_transpiler=seed, skip_qobj_validation = False, shots = 8192)

        qaoa = QAOA(qubitOp_docplex,optimizer=spsa, p=3,include_custom=True)
        result = qaoa.run(quantum_instance)
        print(result['optimal_point'])
        #print('QAOA vector:', result['eigenstate'])
        print('QAOA time:', result['optimizer_time'])
        print('QAOA QAP objective:', result['eigenvalue'] + offset_docplex)
        x = choose_best_feasible(result['eigenstate'])
        print(x,i)
        if x == False:
            soln = 'No solution' #note fails if false
        else:
            soln = qap_value(x[0],MatrixFlow,MatrixLoc) #note fails if false
        print(soln)
        machinesolutions.append([soln, result['optimizer_time'],x,i])
    print(machinesolutions)
    return machinesolutions

# %%
import logging
logging.basicConfig(level=logging.DEBUG) # log the steps of the algorithm and results
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
ins = "made5.csv"
start = 1
stop = 5
step = 1
ans = testing_quantum(ins, start, stop, step)
# Out:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: qap5
#
# Minimize
#  obj: [ 400 x_0_0*x_1_2 + 600 x_0_0*x_1_4 + 400 x_0_0*x_2_2 + 600 x_0_0*x_2_4
#       + 752 x_0_0*x_3_2 + 1128 x_0_0*x_3_4 + 400 x_0_0*x_4_2 + 600 x_0_0*x_4_4
#       + 600 x_0_1*x_1_3 + 600 x_0_1*x_2_3 + 1128 x_0_1*x_3_3 + 600 x_0_1*x_4_3
#       + 400 x_0_2*x_1_0 + 400 x_0_2*x_2_0 + 752 x_0_2*x_3_0 + 400 x_0_2*x_4_0
#       + 600 x_0_3*x_1_1 + 200 x_0_3*x_1_4 + 600 x_0_3*x_2_1 + 200 x_0_3*x_2_4
#       + 1128 x_0_3*x_3_1 + 376 x_0_3*x_3_4 + 600 x_0_3*x_4_1 + 200 x_0_3*x_4_4
#       + 600 x_0_4*x_1_0 + 200 x_0_4*x_1_3 + 600 x_0_4*x_2_0 + 200 x_0_4*x_2_3
#       + 1128 x_0_4*x_3_0 + 376 x_0_4*x_3_3 + 600 x_0_4*x_4_0 + 200 x_0_4*x_4_3
#       + 176 x_1_0*x_2_2 + 264 x_1_0*x_2_4 + 400 x_1_0*x_3_2 + 600 x_1_0*x_3_4
#       + 288 x_1_0*x_4_2 + 432 x_1_0*x_4_4 + 264 x_1_1*x_2_3 + 600 x_1_1*x_3_3
#       + 432 x_1_1*x_4_3 + 176 x_1_2*x_2_0 + 400 x_1_2*x_3_0 + 288 x_1_2*x_4_0
#       + 264 x_1_3*x_2_1 + 88 x_1_3*x_2_4 + 600 x_1_3*x_3_1 + 200 x_1_3*x_3_4
#       + 432 x_1_3*x_4_1 + 144 x_1_3*x_4_4 + 264 x_1_4*x_2_0 + 88 x_1_4*x_2_3
#       + 600 x_1_4*x_3_0 + 200 x_1_4*x_3_3 + 432 x_1_4*x_4_0 + 144 x_1_4*x_4_3
#       + 352 x_2_0*x_3_2 + 528 x_2_0*x_3_4 + 112 x_2_0*x_4_2 + 168 x_2_0*x_4_4
#       + 528 x_2_1*x_3_3 + 168 x_2_1*x_4_3 + 352 x_2_2*x_3_0 + 112 x_2_2*x_4_0
#       + 528 x_2_3*x_3_1 + 176 x_2_3*x_3_4 + 168 x_2_3*x_4_1 + 56 x_2_3*x_4_4
#       + 528 x_2_4*x_3_0 + 176 x_2_4*x_3_3 + 168 x_2_4*x_4_0 + 56 x_2_4*x_4_3
#       + 400 x_3_0*x_4_2 + 600 x_3_0*x_4_4 + 600 x_3_1*x_4_3 + 400 x_3_2*x_4_0
#       + 600 x_3_3*x_4_1 + 200 x_3_3*x_4_4 + 600 x_3_4*x_4_0 + 200 x_3_4*x_4_3
#       ]/2
# Subject To
#  c1: x_0_0 + x_0_1 + x_0_2 + x_0_3 + x_0_4 = 1
#  c2: x_1_0 + x_1_1 + x_1_2 + x_1_3 + x_1_4 = 1
#  c3: x_2_0 + x_2_1 + x_2_2 + x_2_3 + x_2_4 = 1
#  c4: x_3_0 + x_3_1 + x_3_2 + x_3_3 + x_3_4 = 1
#  c5: x_4_0 + x_4_1 + x_4_2 + x_4_3 + x_4_4 = 1
#  c6: x_0_0 + x_1_0 + x_2_0 + x_3_0 + x_4_0 = 1
#  c7: x_0_1 + x_1_1 + x_2_1 + x_3_1 + x_4_1 = 1
#  c8: x_0_2 + x_1_2 + x_2_2 + x_3_2 + x_4_2 = 1
#  c9: x_0_3 + x_1_3 + x_2_3 + x_3_3 + x_4_3 = 1
#  c10: x_0_4 + x_1_4 + x_2_4 + x_3_4 + x_4_4 = 1
#
# Bounds
#  0 <= x_0_0 <= 1
#  0 <= x_0_1 <= 1
#  0 <= x_0_2 <= 1
#  0 <= x_0_3 <= 1
#  0 <= x_0_4 <= 1
#  0 <= x_1_0 <= 1
#  0 <= x_1_1 <= 1
#  0 <= x_1_2 <= 1
#  0 <= x_1_3 <= 1
#  0 <= x_1_4 <= 1
#  0 <= x_2_0 <= 1
#  0 <= x_2_1 <= 1
#  0 <= x_2_2 <= 1
#  0 <= x_2_3 <= 1
#  0 <= x_2_4 <= 1
#  0 <= x_3_0 <= 1
#  0 <= x_3_1 <= 1
#  0 <= x_3_2 <= 1
#  0 <= x_3_3 <= 1
#  0 <= x_3_4 <= 1
#  0 <= x_4_0 <= 1
#  0 <= x_4_1 <= 1
#  0 <= x_4_2 <= 1
#  0 <= x_4_3 <= 1
#  0 <= x_4_4 <= 1
#
# Binaries
#  x_0_0 x_0_1 x_0_2 x_0_3 x_0_4 x_1_0 x_1_1 x_1_2 x_1_3 x_1_4 x_2_0 x_2_1 x_2_2
#  x_2_3 x_2_4 x_3_0 x_3_1 x_3_2 x_3_3 x_3_4 x_4_0 x_4_1 x_4_2 x_4_3 x_4_4
# End
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.99945 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.aqua.quantum_instance:
# Qiskit Terra version: 0.16.2
# Backend: 'qasm_simulator (AerProvider)', with following setting:
# {'basis_gates': ['ccx', 'cp', 'cx', 'cz', 'delay', 'h', 'id', 'kraus', 'p', 'roerror', 's', 'sdg', 'snapshot', 'swap', 'sx', 't', 'tdg', 'u', 'u1', 'u2', 'u3', 'unitary', 'x', 'y', 'z'], 'coupling_map': None}
# {'initial_layout': None, 'seed_transpiler': 10598, 'optimization_level': None}
# RunConfig(max_credits=10, seed_simulator=10598, shots=8192)
# {'timeout': None}
# {}
# {}
# Measurement mitigation: None
# INFO:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:
# ==================== Setting of QAOA ============================
# Algorithm: QAOA
# -- p: 3
# -- mixer_operator: None
# -- initial_state: None
# -- max_evals_grouped: 1
# -- circuit_sampler: None
# -- expectation: None
# -- user_valid_expectation: False
# -- include_custom: True
# -- expect_op: None
# -- operator: SummedOp([
#   50.0 * IIIIIIIIIIIIIIIIIIIZIIZII,
#   -49927.0 * IIIIIIIIIIIIIIIIIIIIIIZII,
#   -50078.0 * IIIIIIIIIIIIIIIIIIIZIIIII,
#   75.0 * IIIIIIIIIIIIIIIIIIIZZIIII,
#   -50171.0 * IIIIIIIIIIIIIIIIIIIIZIIII,
#   75.0 * IIIIIIIIIIIIIIIIIIZIIZIII,
#   -50171.0 * IIIIIIIIIIIIIIIIIIIIIZIII,
#   -49920.0 * IIIIIIIIIIIIIIIIIIZIIIIII,
#   50.0 * IIIIIIIIIIIIIIIIIZIIIIIIZ,
#   -50293.0 * IIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -49841.0 * IIIIIIIIIIIIIIIIIZIIIIIII,
#   75.0 * IIIIIIIIIIIIIIIIZIIIIIIZI,
#   -50049.0 * IIIIIIIIIIIIIIIIIIIIIIIZI,
#   -49999.0 * IIIIIIIIIIIIIIIIZIIIIIIII,
#   25.0 * IIIIIIIIIIIIIIIIZIIIZIIII,
#   75.0 * IIIIIIIIIIIIIIIZIIIIIIIIZ,
#   -49999.0 * IIIIIIIIIIIIIIIZIIIIIIIII,
#   25.0 * IIIIIIIIIIIIIIIZIIIIIZIII,
#   50.0 * IIIIIIIIIIIIIIZIIIIIIIZII,
#   -50008.0 * IIIIIIIIIIIIIIZIIIIIIIIII,
#   75.0 * IIIIIIIIIIIII
# -- parameterized_circuits: None
# -- ret: None
# -- eval_time: None
# -- callback: None
# -- aux_op_nones: []
# -- aux_operators: []
# -- eval_count: 0
# ===============================================================
# Variational Form: QAOAVarForm
# -- num_parameters: 6
# -- num_qubits: 25
# -- bounds: [(0, 3.141592653589793), (0, 3.141592653589793), (0, 3.141592653589793), (0, 6.283185307179586), (0, 6.283185307179586), (0, 6.283185307179586)]
# -- preferred_init_points: [0, 0, 0, 0, 0, 0]
# -- support_parameterized_circuit: True
# -- cost_operator: SummedOp([
#   50.0 * IIIIIIIIIIIIIIIIIIIZIIZII,
#   -49927.0 * IIIIIIIIIIIIIIIIIIIIIIZII,
#   -50078.0 * IIIIIIIIIIIIIIIIIIIZIIIII,
#   75.0 * IIIIIIIIIIIIIIIIIIIZZIIII,
#   -50171.0 * IIIIIIIIIIIIIIIIIIIIZIIII,
#   75.0 * IIIIIIIIIIIIIIIIIIZIIZIII,
#   -50171.0 * IIIIIIIIIIIIIIIIIIIIIZIII,
#   -49920.0 * IIIIIIIIIIIIIIIIIIZIIIIII,
#   50.0 * IIIIIIIIIIIIIIIIIZIIIIIIZ,
#   -50293.0 * IIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -49841.0 * IIIIIIIIIIIIIIIIIZIIIIIII,
#   75.0 * IIIIIIIIIIIIIIIIZIIIIIIZI,
#   -50049.0 * IIIIIIIIIIIIIIIIIIIIIIIZI,
#   -49999.0 * IIIIIIIIIIIIIIIIZIIIIIIII,
#   25.0 * IIIIIIIIIIIIIIIIZIIIZIIII,
#   75.0 * IIIIIIIIIIIIIIIZIIIIIIIIZ,
#   -49999.0 * IIIIIIIIIIIIIIIZIIIIIIIII,
#   25.0 * IIIIIIIIIIIIIIIZIIIIIZIII,
#   50.0 * IIIIIIIIIIIIIIZIIIIIIIZII,
#   -50008.0 * IIIIIIIIIIIIIIZIIIIIIIIII,
#   75.0 * IIIIIIIIIIIIIIZIIIIIZIIII,
#   75.0 * IIIIIIIIIIIIIZIIIIIIIZIII,
#   -49878.0 * IIIIIIIIIIIIIZIIIIIIIIIII,
#   50.0 * IIIIIIIIIIIIZIIIIIIIIIIIZ,
#   -49813.0 * IIIIIIIIIIIIZIIIIIIIIIIII,
#   75.0 * IIIIIIIIIIIZIIIIIIIIIIIZI,
#   -49943.0 * IIIIIIIIIIIZIIIIIIIIIIIII,
#   25.0 * IIIIIIIIIIIZIIIIIIIIZIIII,
#   75.0 * IIIIIIIIIIZIIIIIIIIIIIIIZ,
#   -49943.0 * IIIIIIIIIIZIIIIIIIIIIIIII,
#   25.0 * IIIIIIIIIIZIIIIIIIIIIZIII,
#   94.0 * IIIIIIIIIZIIIIIIIIIIIIZII,
#   -50278.0 * IIIIIIIIIZIIIIIIIIIIIIIII,
#   141.0 * IIIIIIIIIZIIIIIIIIIIZIIII,
#   141.0 * IIIIIIIIZIIIIIIIIIIIIZIII,
#   -50040.0 * IIIIIIIIZIIIIIIIIIIIIIIII,
#   94.0 * IIIIIIIZIIIIIIIIIIIIIIIIZ,
#   -49921.0 * IIIIIIIZIIIIIIIIIIIIIIIII,
#   141.0 * IIIIIIZIIIIIIIIIIIIIIIIZI,
#   -50159.0 * IIIIIIZIIIIIIIIIIIIIIIIII,
#   47.0 * IIIIIIZIIIIIIIIIIIIIZIIII,
#   141.0 * IIIIIZIIIIIIIIIIIIIIIIIIZ,
#   -50159.0 * IIIIIZIIIIIIIIIIIIIIIIIII,
#   47.0 * IIIIIZIIIIIIIIIIIIIIIZIII,
#   50.0 * IIIIZIIIIIIIIIIIIIIIIIZII,
#   -50058.0 * IIIIZIIIIIIIIIIIIIIIIIIII,
#   75.0 * II
starting optimizer.
# bounds=[(0, 3.141592653589793), (0, 3.141592653589793), (0, 3.141592653589793), (0, 6.283185307179586), (0, 6.283185307179586), (0, 6.283185307179586)]
# initial point=[0, 0, 0, 0, 0, 0]
# DEBUG:qiskit.aqua.components.optimizers.optimizer:WARNING: SPSA does not support bounds. It will be ignored.
# DEBUG:qiskit.aqua.components.optimizers.spsa:Parameters: [0.62831853 0.1        0.602      0.101      0.        ]
# DEBUG:qiskit.aqua.components.optimizers.spsa:Calibration...
# DEBUG:qiskit.aqua.components.optimizers.spsa:calibration step # 0 of 1
# INFO:qiskit.transpiler.runningpassmanager:Pass: UnrollCustomDefinitions - 5.99527 (ms)
# INFO:qiskit.transpiler.passes.basis.basis_translator:Begin BasisTranslator from source basis {('snapshot', 25), ('measure', 1), ('rz', 1), ('cx', 2), ('h', 1), ('rx', 1)} to target basis {'u3', 'unitary', 'roerror', 't', 'swap', 'u1', 'tdg', 'cz', 'h', 'u', 'z', 'u2', 'ccx', 'sx', 'reset', 'y', 'x', 'cp', 'measure', 'kraus', 'p', 'sdg', 'cx', 's', 'snapshot', 'delay', 'barrier', 'id'}.
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Begining basis search from frozenset({('rx', 1), ('snapshot', 25), ('measure', 1), ('rz', 1), ('cx', 2), ('h', 1)}) to frozenset({'u3', 'unitary', 'roerror', 't', 'swap', 'u1', 'tdg', 'cz', 'h', 'u', 'z', 'u2', 'ccx', 'sx', 'reset', 'y', 'x', 'cp', 'measure', 'kraus', 'p', 'sdg', 'cx', 's', 'snapshot', 'delay', 'barrier', 'id'}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('rx', 1), ('snapshot', 25), ('measure', 1), ('rz', 1), ('cx', 2), ('h', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('u1', 1), ('rx', 1), ('snapshot', 25), ('measure', 1), ('cx', 2), ('h', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('u3', 1), ('rx', 1), ('snapshot', 25), ('measure', 1), ('cx', 2), ('h', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('rx', 1), ('p', 1), ('snapshot', 25), ('measure', 1), ('cx', 2), ('h', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('u1', 1), ('r', 1), ('snapshot', 25), ('measure', 1), ('cx', 2), ('h', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Transformation path:
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:rz/1 => [Parameter(theta)]
# global phase: -0.5*theta
#      ┌───────────┐
# q_0: ┤ U1(theta) ├
#      └───────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:rx/1 => [Parameter(theta)]
#      ┌────────────┐
# q_0: ┤ R(theta,0) ├
#      └────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:r/1 => [Parameter(theta), Parameter(phi)]
#      ┌───────────────────────────────────────────────────────────┐
# q_0: ┤ U3(theta,phi - 1.5707963267949,1.5707963267949 - 1.0*phi) ├
#      └───────────────────────────────────────────────────────────┘
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation path search completed in 0.040s.
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: rz/1 [Parameter(theta)] =>
# global phase: -0.5*theta
#      ┌───────────┐
# q_0: ┤ U1(theta) ├
#      └───────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('rz', 1) rz, ['rz[0]'] from
#       ┌───────────┐
# q2_0: ┤ rz(rz[0]) ├
#       └───────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('rz', 1) rz, ['rz[0]'] to
# global phase: -0.5*rz[0]
#       ┌───────────┐
# q2_0: ┤ U1(rz[0]) ├
#       └───────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: rx/1 [Parameter(theta)] =>
#      ┌────────────┐
# q_0: ┤ R(theta,0) ├
#      └────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('rx', 1) rx, ['rx[0]'] from
#       ┌───────────┐
# q5_0: ┤ rx(rx[0]) ├
#       └───────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('rx', 1) rx, ['rx[0]'] to
#       ┌────────────┐
# q5_0: ┤ R(rx[0],0) ├
#       └────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: r/1 [Parameter(theta), Parameter(phi)] =>
#      ┌───────────────────────────────────────────────────────────┐
# q_0: ┤ U3(theta,phi - 1.5707963267949,1.5707963267949 - 1.0*phi) ├
#      └───────────────────────────────────────────────────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('rx', 1) rx, ['rx[0]'] from
#       ┌────────────┐
# q5_0: ┤ R(rx[0],0) ├
#       └────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('rx', 1) rx, ['rx[0]'] to
#       ┌────────────────────┐
# q5_0: ┤ U3(rx[0],-π/2,π/2) ├
#       └────────────────────┘
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation paths composed in 0.112s.
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation instructions replaced in 1.032s.
# INFO:qiskit.transpiler.runningpassmanager:Pass: BasisTranslator - 1195.85991 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: RemoveResetInZeroState - 2.99859 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 0.99969 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 29.98161 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CXCancellation - 17.98797 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 0.99897 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 19.98663 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CXCancellation - 25.98262 (ms)
# INFO:qiskit.compiler.transpile:Total Transpile Time - 1833.57716 (ms)
# DEBUG:qiskit.aqua.quantum_instance:==== Before transpiler ====
# DEBUG:qiskit.aqua.quantum_instance:Submitting 1 circuits.
# ============================================================================
# 0-th circuit: 25 qubits, 25 classical bits and 1820 operations with depth 227
# op_counts: OrderedDict([('cx', 1080), ('rz', 615), ('rx', 75), ('h', 25), ('measure', 25), ('snapshot', 1)])
# ============================================================================
#
# DEBUG:qiskit.aqua.quantum_instance:====  After transpiler ====
# DEBUG:qiskit.aqua.quantum_instance:Submitting 1 circuits.
# ============================================================================
# 0-th circuit: 25 qubits, 25 classical bits and 1820 operations with depth 227
# op_counts: OrderedDict([('cx', 1080), ('u1', 615), ('u3', 75), ('h', 25), ('measure', 25), ('snapshot', 1)])
# ============================================================================
#
# DEBUG:qiskit.aqua.operators.converters.circuit_sampler:Parameter conversion 840.20424 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)

# %%
import logging
logging.basicConfig(level=logging.DEBUG) # log the steps of the algorithm and results
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
ins = "made9.csv"
start = 1
stop = 2
step = 1
ans = testing_quantum(ins, start, stop, step)
# Out:
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: qap9
#
# Minimize
#  obj: [ 256 x_0_0*x_1_1 + 512 x_0_0*x_1_2 + 256 x_0_0*x_1_6 + 544 x_0_0*x_2_1
#       + 1088 x_0_0*x_2_2 + 544 x_0_0*x_2_6 + 776 x_0_0*x_3_1 + 1552 x_0_0*x_3_2
#       + 776 x_0_0*x_3_6 + 600 x_0_0*x_4_1 + 1200 x_0_0*x_4_2 + 600 x_0_0*x_4_6
#       + 560 x_0_0*x_5_1 + 1120 x_0_0*x_5_2 + 560 x_0_0*x_5_6 + 600 x_0_0*x_6_1
#       + 1200 x_0_0*x_6_2 + 600 x_0_0*x_6_6 + 320 x_0_0*x_7_1 + 640 x_0_0*x_7_2
#       + 320 x_0_0*x_7_6 + 192 x_0_0*x_8_1 + 384 x_0_0*x_8_2 + 192 x_0_0*x_8_6
#       + 256 x_0_1*x_1_0 + 384 x_0_1*x_1_2 + 128 x_0_1*x_1_3 + 128 x_0_1*x_1_5
#       + 256 x_0_1*x_1_8 + 544 x_0_1*x_2_0 + 816 x_0_1*x_2_2 + 272 x_0_1*x_2_3
#       + 272 x_0_1*x_2_5 + 544 x_0_1*x_2_8 + 776 x_0_1*x_3_0 + 1164 x_0_1*x_3_2
#       + 388 x_0_1*x_3_3 + 388 x_0_1*x_3_5 + 776 x_0_1*x_3_8 + 600 x_0_1*x_4_0
#       + 900 x_0_1*x_4_2 + 300 x_0_1*x_4_3 + 300 x_0_1*x_4_5 + 600 x_0_1*x_4_8
#       + 560 x_0_1*x_5_0 + 840 x_0_1*x_5_2 + 280 x_0_1*x_5_3 + 280 x_0_1*x_5_5
#       + 560 x_0_1*x_5_8 + 600 x_0_1*x_6_0 + 900 x_0_1*x_6_2 + 300 x_0_1*x_6_3
#       + 300 x_0_1*x_6_5 + 600 x_0_1*x_6_8 + 320 x_0_1*x_7_0 + 480 x_0_1*x_7_2
#       + 160 x_0_1*x_7_3 + 160 x_0_1*x_7_5 + 320 x_0_1*x_7_8 + 192 x_0_1*x_8_0
#       + 288 x_0_1*x_8_2 + 96 x_0_1*x_8_3 + 96 x_0_1*x_8_5 + 192 x_0_1*x_8_8
#       + 512 x_0_2*x_1_0 + 384 x_0_2*x_1_1 + 128 x_0_2*x_1_5 + 1088 x_0_2*x_2_0
#       + 816 x_0_2*x_2_1 + 272 x_0_2*x_2_5 + 1552 x_0_2*x_3_0 + 1164 x_0_2*x_3_1
#       + 388 x_0_2*x_3_5 + 1200 x_0_2*x_4_0 + 900 x_0_2*x_4_1 + 300 x_0_2*x_4_5
#       + 1120 x_0_2*x_5_0 + 840 x_0_2*x_5_1 + 280 x_0_2*x_5_5 + 1200 x_0_2*x_6_0
#       + 900 x_0_2*x_6_1 + 300 x_0_2*x_6_5 + 640 x_0_2*x_7_0 + 480 x_0_2*x_7_1
#       + 160 x_0_2*x_7_5 + 384 x_0_2*x_8_0 + 288 x_0_2*x_8_1 + 96 x_0_2*x_8_5
#       + 128 x_0_3*x_1_1 + 384 x_0_3*x_1_4 + 128 x_0_3*x_1_6 + 640 x_0_3*x_1_7
#       + 272 x_0_3*x_2_1 + 816 x_0_3*x_2_4 + 272 x_0_3*x_2_6 + 1360 x_0_3*x_2_7
#       + 388 x_0_3*x_3_1 + 1164 x_0_3*x_3_4 + 388 x_0_3*x_3_6 + 1940 x_0_3*x_3_7
#       + 300 x_0_3*x_4_1 + 900 x_0_3*x_4_4 + 300 x_0_3*x_4_6 + 1500 x_0_3*x_4_7
#       + 280 x_0_3*x_5_1 + 840 x_0_3*x_5_4 + 280 x_0_3*x_5_6 + 1400 x_0_3*x_5_7
#       + 300 x_0_3*x_6_1 + 900 x_0_3*x_6_4 + 300 x_0_3*x_6_6 + 1500 x_0_3*x_6_7
#       + 160 x_0_3*x_7_1 + 480 x_0_3*x_7_4 + 160 x_0_3*x_7_6 + 800 x_0_3*x_7_7
#       + 96 x_0_3*x_8_1 + 288 x_0_3*x_8_4 + 96 x_0_3*x_8_6 + 480 x_0_3*x_8_7
#       + 384 x_0_4*x_1_3 + 816 x_0_4*x_2_3 + 1164 x_0_4*x_3_3 + 900 x_0_4*x_4_3
#       + 840 x_0_4*x_5_3 + 900 x_0_4*x_6_3 + 480 x_0_4*x_7_3 + 288 x_0_4*x_8_3
#       + 128 x_0_5*x_1_1 + 128 x_0_5*x_1_2 + 256 x_0_5*x_1_8 + 272 x_0_5*x_2_1
#       + 272 x_0_5*x_2_2 + 544 x_0_5*x_2_8 + 388 x_0_5*x_3_1 + 388 x_0_5*x_3_2
#       + 776 x_0_5*x_3_8 + 300 x_0_5*x_4_1 + 300 x_0_5*x_4_2 + 600 x_0_5*x_4_8
#       + 288 x_6_6*x_7_0 + 144 x_6_6*x_7_3 + 576 x_6_6*x_7_7 + 432 x_6_6*x_7_8
#       + 448 x_6_6*x_8_0 + 224 x_6_6*x_8_3 + 896 x_6_6*x_8_7 + 672 x_6_6*x_8_8
#       + 720 x_6_7*x_7_3 + 576 x_6_7*x_7_6 + 1120 x_6_7*x_8_3 + 896 x_6_7*x_8_6
#       + 288 x_6_8*x_7_1 + 288 x_6_8*x_7_5 + 432 x_6_8*x_7_6 + 448 x_6_8*x_8_1
#       + 448 x_6_8*x_8_5 + 672 x_6_8*x_8_6 + 152 x_7_0*x_8_1 + 304 x_7_0*x_8_2
#       + 152 x_7_0*x_8_6 + 152 x_7_1*x_8_0 + 228 x_7_1*x_8_2 + 76 x_7_1*x_8_3
#       + 76 x_7_1*x_8_5 + 152 x_7_1*x_8_8 + 304 x_7_2*x_8_0 + 228 x_7_2*x_8_1
#       + 76 x_7_2*x_8_5 + 76 x_7_3*x_8_1 + 228 x_7_3*x_8_4 + 76 x_7_3*x_8_6
#       + 380 x_7_3*x_8_7 + 228 x_7_4*x_8_3 + 76 x_7_5*x_8_1 + 76 x_7_5*x_8_2
#       + 152 x_7_5*x_8_8 + 152 x_7_6*x_8_0 + 76 x_7_6*x_8_3 + 304 x_7_6*x_8_7
#       + 228 x_7_6*x_8_8 + 380 x_7_7*x_8_3 + 304 x_7_7*x_8_6 + 152 x_7_8*x_8_1
#       + 152 x_7_8*x_8_5 + 228 x_7_8*x_8_6 ]/2
# Subject To
#  c1: x_0_0 + x_0_1 + x_0_2 + x_0_3 + x_0_4 + x_0_5 + x_0_6 + x_0_7 + x_0_8 = 1
#  c2: x_1_0 + x_1_1 + x_1_2 + x_1_3 + x_1_4 + x_1_5 + x_1_6 + x_1_7 + x_1_8 = 1
#  c3: x_2_0 + x_2_1 + x_2_2 + x_2_3 + x_2_4 + x_2_5 + x_2_6 + x_2_7 + x_2_8 = 1
#  c4: x_3_0 + x_3_1 + x_3_2 + x_3_3 + x_3_4 + x_3_5 + x_3_6 + x_3_7 + x_3_8 = 1
#  c5: x_4_0 + x_4_1 + x_4_2 + x_4_3 + x_4_4 + x_4_5 + x_4_6 + x_4_7 + x_4_8 = 1
#  c6: x_5_0 + x_5_1 + x_5_2 + x_5_3 + x_5_4 + x_5_5 + x_5_6 + x_5_7 + x_5_8 = 1
#  c7: x_6_0 + x_6_1 + x_6_2 + x_6_3 + x_6_4 + x_6_5 + x_6_6 + x_6_7 + x_6_8 = 1
#  c8: x_7_0 + x_7_1 + x_7_2 + x_7_3 + x_7_4 + x_7_5 + x_7_6 + x_7_7 + x_7_8 = 1
#  c9: x_8_0 + x_8_1 + x_8_2 + x_8_3 + x_8_4 + x_8_5 + x_8_6 + x_8_7 + x_8_8 = 1
#  c10: x_0_0 + x_1_0 + x_2_0 + x_3_0 + x_4_0 + x_5_0 + x_6_0 + x_7_0 + x_8_0 = 1
#  c11: x_0_1 + x_1_1 + x_2_1 + x_3_1 + x_4_1 + x_5_1 + x_6_1 + x_7_1 + x_8_1 = 1
#  c12: x_0_2 + x_1_2 + x_2_2 + x_3_2 + x_4_2 + x_5_2 + x_6_2 + x_7_2 + x_8_2 = 1
#  c13: x_0_3 + x_1_3 + x_2_3 + x_3_3 + x_4_3 + x_5_3 + x_6_3 + x_7_3 + x_8_3 = 1
#  c14: x_0_4 + x_1_4 + x_2_4 + x_3_4 + x_4_4 + x_5_4 + x_6_4 + x_7_4 + x_8_4 = 1
#  c15: x_0_5 + x_1_5 + x_2_5 + x_3_5 + x_4_5 + x_5_5 + x_6_5 + x_7_5 + x_8_5 = 1
#  c16: x_0_6 + x_1_6 + x_2_6 + x_3_6 + x_4_6 + x_5_6 + x_6_6 + x_7_6 + x_8_6 = 1
#  c17: x_0_7 + x_1_7 + x_2_7 + x_3_7 + x_4_7 + x_5_7 + x_6_7 + x_7_7 + x_8_7 = 1
#  c18: x_0_8 + x_1_8 + x_2_8 + x_3_8 + x_4_8 + x_5_8 + x_6_8 + x_7_8 + x_8_8 = 1
#
# Bounds
#  0 <= x_0_0 <= 1
#  0 <= x_0_1 <= 1
#  0 <= x_0_2 <= 1
#  0 <= x_0_3 <= 1
#  0 <= x_0_4 <= 1
#  0 <= x_0_5 <= 1
#  0 <= x_0_6 <= 1
#  0 <= x_0_7 <= 1
#  0 <= x_0_8 <= 1
#  0 <= x_1_0 <= 1
#  0 <= x_1_1 <= 1
#  0 <= x_1_2 <= 1
#  0 <= x_1_3 <= 1
#  0 <= x_1_4 <= 1
#  0 <= x_1_5 <= 1
#  0 <= x_1_6 <= 1
#  0 <= x_1_7 <= 1
#  0 <= x_1_8 <= 1
#  0 <= x_2_0 <= 1
#  0 <= x_2_1 <= 1
#  0 <= x_2_2 <= 1
#  0 <= x_2_3 <= 1
#  0 <= x_2_4 <= 1
#  0 <= x_2_5 <= 1
#  0 <= x_2_6 <= 1
#  0 <= x_2_7 <= 1
#  0 <= x_2_8 <= 1
#  0 <= x_3_0 <= 1
#  0 <= x_3_1 <= 1
#  0 <= x_3_2 <= 1
#  0 <= x_3_3 <= 1
#  0 <= x_3_4 <= 1
#  0 <= x_3_5 <= 1
#  0 <= x_3_6 <= 1
#  0 <= x_3_7 <= 1
#  0 <= x_3_8 <= 1
#  0 <= x_4_0 <= 1
#  0 <= x_4_1 <= 1
#  0 <= x_4_2 <= 1
#  0 <= x_4_3 <= 1
#  0 <= x_4_4 <= 1
#  0 <= x_4_5 <= 1
#  0 <= x_4_6 <= 1
#  0 <= x_4_7 <= 1
#  0 <= x_4_8 <= 1
#  0 <= x_5_0 <= 1
#  0 <= x_5_1 <= 1
#  0 <= x_5_2 <= 1
#  0 <= x_5_3 <= 1
#  0 <= x_5_4 <= 1
#  0 <= x_5_5 <= 1
#  0 <= x_5_6 <= 1
#  0 <= x_5_7 <= 1
#  0 <= x_5_8 <= 1
#  0 <= x_6_0 <= 1
#  0 <= x_6_1 <= 1
#  0 <= x_6_2 <= 1
#  0 <= x_6_3 <= 1
#  0 <= x_6_4 <= 1
#  0 <= x_6_5 <= 1
#  0 <= x_6_6 <= 1
#  0 <= x_6_7 <= 1
#  0 <= x_6_8 <= 1
#  0 <= x_7_0 <= 1
#  0 <= x_7_1 <= 1
#  0 <= x_7_2 <= 1
#  0 <= x_7_3 <= 1
#  0 <= x_7_4 <= 1
#  0 <= x_7_5 <= 1
#  0 <= x_7_6 <= 1
#  0 <= x_7_7 <= 1
#  0 <= x_7_8 <= 1
#  0 <= x_8_0 <= 1
#  0 <= x_8_1 <= 1
#  0 <= x_8_2 <= 1
#  0 <= x_8_3 <= 1
#  0 <= x_8_4 <= 1
#  0 <= x_8_5 <= 1
#  0 <= x_8_6 <= 1
#  0 <= x_8_7 <= 1
#  0 <= x_8_8 <= 1
#
# Binaries
#  x_0_0 x_0_1 x_0_2 x_0_3 x_0_4 x_0_5 x_0_6 x_0_7 x_0_8 x_1_0 x_1_1 x_1_2 x_1_3
#  x_1_4 x_1_5 x_1_6 x_1_7 x_1_8 x_2_0 x_2_1 x_2_2 x_2_3 x_2_4 x_2_5 x_2_6 x_2_7
#  x_2_8 x_3_0 x_3_1 x_3_2 x_3_3 x_3_4 x_3_5 x_3_6 x_3_7 x_3_8 x_4_0 x_4_1 x_4_2
#  x_4_3 x_4_4 x_4_5 x_4_6 x_4_7 x_4_8 x_5_0 x_5_1 x_5_2 x_5_3 x_5_4 x_5_5 x_5_6
#  x_5_7 x_5_8 x_6_0 x_6_1 x_6_2 x_6_3 x_6_4 x_6_5 x_6_6 x_6_7 x_6_8 x_7_0 x_7_1
#  x_7_2 x_7_3 x_7_4 x_7_5 x_7_6 x_7_7 x_7_8 x_8_0 x_8_1 x_8_2 x_8_3 x_8_4 x_8_5
#  x_8_6 x_8_7 x_8_8
# End
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.aqua.quantum_instance:
# Qiskit Terra version: 0.16.2
# Backend: 'qasm_simulator (AerProvider)', with following setting:
# {'basis_gates': ['ccx', 'cp', 'cx', 'cz', 'delay', 'h', 'id', 'kraus', 'p', 'roerror', 's', 'sdg', 'snapshot', 'swap', 'sx', 't', 'tdg', 'u', 'u1', 'u2', 'u3', 'unitary', 'x', 'y', 'z'], 'coupling_map': None}
# {'initial_layout': None, 'seed_transpiler': 10598, 'optimization_level': None}
# RunConfig(max_credits=10, seed_simulator=10598, shots=8192)
# {'timeout': None}
# {}
# {}
# Measurement mitigation: None
# INFO:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:
# ==================== Setting of QAOA ============================
# Algorithm: QAOA
# -- p: 3
# -- mixer_operator: None
# -- initial_state: None
# -- max_evals_grouped: 1
# -- circuit_sampler: None
# -- expectation: None
# -- user_valid_expectation: False
# -- include_custom: True
# -- expect_op: None
# -- operator: SummedOp([
#   32.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIZI,
#   -1786219.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1785775.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIII,
#   64.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIZII,
#   -1785979.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZII,
#   32.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIZIIIIII,
#   -1786460.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   32.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIZ,
#   -1785979.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -1785990.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIII,
#   48.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIZII,
#   16.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIZIII,
#   -1786460.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   16.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIZIIIII,
#   -1785017.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIII,
#   32.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIZIIIIIIII,
#   -1785738.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIII,
#   64.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIZ,
#   -1785775.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIII,
#   48.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIZI,
#   16.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIZIIIII,
#   16.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIZI,
#   -1786205.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIII,
#   48.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIZIIII,
#   -1784776.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIII,
#   16.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIZIIIIII,
#   80.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIZIIIIIII,
#   -1786219.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIII,
#   48.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIZIII,
#   -1784700.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIII,
#   16.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIZI,
#   -1784915.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIII,
#   16.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIZII,
#   32.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIZIIIIIIII,
#   32.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIZ,
#   -1786205.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIII,
#   16.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIZIII,
#   64.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIZIIIIIII,
#   48.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIZIIIIIIII,
#   80.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIZIII,
#   -1785990.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIII,
#   64.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIZIIIIII,
#   32.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIZI,
#   -1785560.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIII,
#   32.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIZIIIII,
#   48.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIZIIIIII,
#   68.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIZI,
#   -1785667.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIII,
#   136.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIZII,
#   68.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIZIIIIII,
#   68.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIZ,
#   -1785868.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIII,
#   102.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIZII,
#   34.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIZIII,
#   34.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIZIIIII,
#   68.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIZIIIIIIII,
#   136.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIZ,
#   -1785667.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIII,
#   102.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIZI,
#   34.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIZIIIII,
#   34.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIZI,
#   -1786070.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIII,
#   102.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIZIIII,
#   34.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIZIIIIII,
#   170.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIZIIIIIII,
#   102.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIZIII,
#   -1784659.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIII,
#   34.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIZI,
#   -1784861.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIII,
#   34.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIZII,
#   68.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIZIIIIIIII,
#   68.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -1786070.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIII,
#   34.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIZIII,
#   136.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIZIIIIIII,
#   102.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIZIIIIIIII,
#   170.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIZIII,
#   -1785868.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIII,
#   136.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIZIIIIII,
#   68.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1785465.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIII,
#   68.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIZIIIII,
#   102.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIZIIIIII,
#   97.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1786019.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   194.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIZII,
#   97.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   97.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -1786264.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   145.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIZII,
#   48.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   48.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIZIIIII,
#   97.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIZIIIIIIII,
#   194.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -1786019.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   145.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   48.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIZIIIII,
#   48.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1786510.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   145.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIZIIII,
#   48.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   242.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIZIIIIIII,
#   145.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   -1784791.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   48.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1785037.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   48.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZII,
#   97.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIII,
#   97.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -1786510.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   48.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   194.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIII,
#   145.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIII,
#   242.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   -1786264.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   194.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   97.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1785773.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   97.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIII,
#   145.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   75.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1785599.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   150.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZII,
#   75.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   75.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -1785792.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   112.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZII,
#   37.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   37.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIII,
#   75.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIII,
#   150.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -1785599.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   112.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   37.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIII,
#   37.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1785985.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   112.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIII,
#   37.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   187.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIII,
#   112.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   -1784634.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   37.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1784827.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   37.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZII,
#   75.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIII,
#   75.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -1785985.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   37.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   150.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIII,
#   112.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIII,
#   187.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   -1785792.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   150.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   75.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1785406.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   75.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIII,
#   112.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   70.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1785523.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   140.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZII,
#   70.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   70.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -1785706.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   105.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZII,
#   35.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   35.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIII,
#   70.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIII,
#   140.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -1785523.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   105.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   35.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIII,
#   35.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1785890.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   105.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIII,
#   35.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   175.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIII,
#   105.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   -1784605.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   35.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1784789.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   35.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZII,
#   70.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIII,
#   70.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -1785890.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   35.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   140.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIII,
#   105.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIII,
#   175.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   -1785706.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   140.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   70.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1785339.5 * IIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   70.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIII,
#   105.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   75.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1786027.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   150.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZII,
#   75.0 * IIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   75.0 * IIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -1786273.5 * IIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   112.5 * IIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZII,
#   37.5 * IIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   37.5 * IIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIII,
#   75.0 * IIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIII,
#   150.0 * IIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -1786027.0 * IIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   112.5 * IIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   37.5 * IIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIII,
#   37.5 * IIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1786520.0 * IIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   112.5 * IIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIII,
#   37.5 * IIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   187.5 * IIIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIII,
#   112.5 * IIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   -1784794.5 * IIIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   37.5 * IIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1785041.0 * IIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   37.5 * IIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZII,
#   75.0 * IIIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIII,
#   75.0 * IIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -1786520.0 * IIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   37.5 * IIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   150.0 * IIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIII,
#   112.5 * IIIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIII,
#   187.5 * IIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   -1786273.5 * IIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   150.0 * IIIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   75.0 * IIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1785780.5 * IIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   75.0 * IIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIII,
#   112.5 * IIIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   40.0 * IIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1785443.0 * IIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   80.0 * IIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZII,
#   40.0 * IIIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIII,
#   40.0 * IIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -1785616.5 * IIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   60.0 * IIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZII,
#   20.0 * IIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIII,
#   20.0 * IIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIII,
#   40.0 * IIIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIIIIII,
#   80.0 * IIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZ,
#   -1785443.0 * IIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   60.0 * IIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   20.0 * IIIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIIII,
#   20.0 * IIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZI,
#   -1785790.0 * IIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIII,
#   60.0 * IIIIIIIIIIIIIIZIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIIZIIII,
# ...
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('x', 1), ('measure', 1), ('snapshot', 81), ('cz', 2), ('sx', 1), ('h', 1), ('s', 1), ('u3', 1), ('u1', 1), ('rx', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('x', 1), ('measure', 1), ('snapshot', 81), ('cx', 2), ('h', 1), ('s', 1), ('u3', 1), ('sdg', 1), ('u1', 1), ('rx', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('x', 1), ('measure', 1), ('snapshot', 81), ('cx', 2), ('sx', 1), ('u3', 1), ('s', 1), ('u2', 1), ('u1', 1), ('rx', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('x', 1), ('measure', 1), ('snapshot', 81), ('cz', 2), ('sx', 1), ('u3', 1), ('s', 1), ('u2', 1), ('h', 1), ('u1', 1), ('rx', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('x', 1), ('measure', 1), ('snapshot', 81), ('cx', 2), ('u3', 1), ('s', 1), ('u2', 1), ('h', 1), ('sdg', 1), ('u1', 1), ('rx', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('x', 1), ('measure', 1), ('snapshot', 81), ('cx', 2), ('sx', 1), ('u3', 1), ('s', 1), ('u2', 1), ('h', 1), ('u1', 1), ('rx', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('x', 1), ('measure', 1), ('snapshot', 81), ('cz', 2), ('u3', 1), ('s', 1), ('u2', 1), ('h', 1), ('sdg', 1), ('u1', 1), ('rx', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('x', 1), ('measure', 1), ('snapshot', 81), ('cz', 2), ('sx', 1), ('h', 1), ('s', 1), ('u2', 1), ('u1', 1), ('u', 1), ('rx', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('x', 1), ('p', 1), ('measure', 1), ('snapshot', 81), ('cz', 2), ('sx', 1), ('u3', 1), ('s', 1), ('u2', 1), ('h', 1), ('rx', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('x', 1), ('measure', 1), ('r', 1), ('snapshot', 81), ('cz', 2), ('sx', 1), ('u3', 1), ('s', 1), ('u2', 1), ('h', 1), ('u1', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Transformation path:
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:rz/1 => [Parameter(theta)]
# global phase: -0.5*theta
#      ┌───────────┐
# q_0: ┤ U1(theta) ├
#      └───────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:h/1 => []
#      ┌─────────┐
# q_0: ┤ U2(0,π) ├
#      └─────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:cx/2 => []
# global phase: 3π/4
#      ┌───┐     ┌────────┐┌───┐     ┌────────┐┌───┐┌───┐
# q_0: ┤ H ├─────┤0       ├┤ X ├─────┤0       ├┤ H ├┤ S ├─────
#      ├───┤┌───┐│  ISWAP │├───┤┌───┐│  ISWAP │├───┤├───┤┌───┐
# q_1: ┤ X ├┤ H ├┤1       ├┤ X ├┤ H ├┤1       ├┤ S ├┤ X ├┤ H ├
#      └───┘└───┘└────────┘└───┘└───┘└────────┘└───┘└───┘└───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:iswap/2 => []
#      ┌───┐┌───┐     ┌───┐
# q_0: ┤ S ├┤ H ├──■──┤ X ├─────
#      ├───┤└───┘┌─┴─┐└─┬─┘┌───┐
# q_1: ┤ S ├─────┤ X ├──■──┤ H ├
#      └───┘     └───┘     └───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:u1/1 => [Parameter(theta)]
#      ┌───────────────┐
# q_0: ┤ U3(0,0,theta) ├
#      └───────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:u2/1 => [Parameter(phi), Parameter(lam)]
# global phase: -π/4
#      ┌───────────────────────────┐┌────┐┌───────────────────────────┐
# q_0: ┤ U1(lam - 1.5707963267949) ├┤ √X ├┤ U1(phi + 1.5707963267949) ├
#      └───────────────────────────┘└────┘└───────────────────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:h/1 => []
#      ┌─────────┐
# q_0: ┤ U2(0,π) ├
#      └─────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:cx/2 => []
#
# q_0: ──────■──────
#      ┌───┐ │ ┌───┐
# q_1: ┤ H ├─■─┤ H ├
#      └───┘   └───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:rx/1 => [Parameter(theta)]
#      ┌────────────┐
# q_0: ┤ R(theta,0) ├
#      └────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:r/1 => [Parameter(theta), Parameter(phi)]
#      ┌───────────────────────────────────────────────────────────┐
# q_0: ┤ U3(theta,phi - 1.5707963267949,1.5707963267949 - 1.0*phi) ├
#      └───────────────────────────────────────────────────────────┘
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation path search completed in 0.076s.
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: rz/1 [Parameter(theta)] =>
# global phase: -0.5*theta
#      ┌───────────┐
# q_0: ┤ U1(theta) ├
#      └───────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('rz', 1) rz, ['rz[0]'] from
#       ┌───────────┐
# q0_0: ┤ rz(rz[0]) ├
#       └───────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('rz', 1) rz, ['rz[0]'] to
# global phase: -0.5*rz[0]
#       ┌───────────┐
# q0_0: ┤ U1(rz[0]) ├
#       └───────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: h/1 [] =>
#      ┌─────────┐
# q_0: ┤ U2(0,π) ├
#      └─────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('h', 1) h, [] from
#       ┌───┐
# q4_0: ┤ h ├
#       └───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('h', 1) h, [] to
#       ┌─────────┐
# q4_0: ┤ U2(0,π) ├
#       └─────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: cx/2 [] =>
# global phase: 3π/4
#      ┌───┐     ┌────────┐┌───┐     ┌────────┐┌───┐┌───┐
# q_0: ┤ H ├─────┤0       ├┤ X ├─────┤0       ├┤ H ├┤ S ├─────
#      ├───┤┌───┐│  ISWAP │├───┤┌───┐│  ISWAP │├───┤├───┤┌───┐
# q_1: ┤ X ├┤ H ├┤1       ├┤ X ├┤ H ├┤1       ├┤ S ├┤ X ├┤ H ├
#      └───┘└───┘└────────┘└───┘└───┘└────────┘└───┘└───┘└───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('cx', 2) cx, [] from
#       ┌─────┐
# q3_0: ┤0    ├
#       │  cx │
# q3_1: ┤1    ├
#       └─────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('cx', 2) cx, [] to
# global phase: 3π/4
#       ┌───┐     ┌────────┐┌───┐     ┌────────┐┌───┐┌───┐
# q3_0: ┤ H ├─────┤0       ├┤ X ├─────┤0       ├┤ H ├┤ S ├─────
#       ├───┤┌───┐│  ISWAP │├───┤┌───┐│  ISWAP │├───┤├───┤┌───┐
# q3_1: ┤ X ├┤ H ├┤1       ├┤ X ├┤ H ├┤1       ├┤ S ├┤ X ├┤ H ├
#       └───┘└───┘└────────┘└───┘└───┘└────────┘└───┘└───┘└───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: iswap/2 [] =>
#      ┌───┐┌───┐     ┌───┐
# q_0: ┤ S ├┤ H ├──■──┤ X ├─────
#      ├───┤└───┘┌─┴─┐└─┬─┘┌───┐
# q_1: ┤ S ├─────┤ X ├──■──┤ H ├
#      └───┘     └───┘     └───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('cx', 2) cx, [] from
# global phase: 3π/4
#       ┌───┐     ┌────────┐┌───┐     ┌────────┐┌───┐┌───┐
# q3_0: ┤ H ├─────┤0       ├┤ X ├─────┤0       ├┤ H ├┤ S ├─────
#       ├───┤┌───┐│  ISWAP │├───┤┌───┐│  ISWAP │├───┤├───┤┌───┐
# q3_1: ┤ X ├┤ H ├┤1       ├┤ X ├┤ H ├┤1       ├┤ S ├┤ X ├┤ H ├
#       └───┘└───┘└────────┘└───┘└───┘└────────┘└───┘└───┘└───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('cx', 2) cx, [] to
# global phase: 3π/4
#       ┌───┐┌───┐┌───┐     ┌───┐┌───┐┌───┐┌───┐          ┌───┐┌───┐┌───┐     »
# q3_0: ┤ H ├┤ S ├┤ H ├──■──┤ X ├┤ X ├┤ S ├┤ H ├───────■──┤ X ├┤ H ├┤ S ├─────»
#       ├───┤├───┤├───┤┌─┴─┐└─┬─┘├───┤├───┤├───┤┌───┐┌─┴─┐└─┬─┘├───┤├───┤┌───┐»
# q3_1: ┤ X ├┤ H ├┤ S ├┤ X ├──■──┤ H ├┤ X ├┤ H ├┤ S ├┤ X ├──■──┤ H ├┤ S ├┤ X ├»
#       └───┘└───┘└───┘└───┘     └───┘└───┘└───┘└───┘└───┘     └───┘└───┘└───┘»
# «
# «q3_0: ─────
# «      ┌───┐
# «q3_1: ┤ H ├
# «      └───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: u1/1 [Parameter(theta)] =>
#      ┌───────────────┐
# q_0: ┤ U3(0,0,theta) ├
#      └───────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('rz', 1) rz, ['rz[0]'] from
# global phase: -0.5*rz[0]
#       ┌───────────┐
# q0_0: ┤ U1(rz[0]) ├
#       └───────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('rz', 1) rz, ['rz[0]'] to
# global phase: -0.5*rz[0]
#       ┌───────────────┐
# q0_0: ┤ U3(0,0,rz[0]) ├
#       └───────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: u2/1 [Parameter(phi), Parameter(lam)] =>
# global phase: -π/4
#      ┌───────────────────────────┐┌────┐┌───────────────────────────┐
# q_0: ┤ U1(lam - 1.5707963267949) ├┤ √X ├┤ U1(phi + 1.5707963267949) ├
#      └───────────────────────────┘└────┘└───────────────────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('h', 1) h, [] from
#       ┌─────────┐
# q4_0: ┤ U2(0,π) ├
#       └─────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('h', 1) h, [] to
# global phase: -π/4
#       ┌─────────┐┌────┐┌─────────┐
# q4_0: ┤ U1(π/2) ├┤ √X ├┤ U1(π/2) ├
#       └─────────┘└────┘└─────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: h/1 [] =>
#      ┌─────────┐
# q_0: ┤ U2(0,π) ├
#      └─────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('cx', 2) cx, [] from
# global phase: 3π/4
#       ┌───┐┌───┐┌───┐     ┌───┐┌───┐┌───┐┌───┐          ┌───┐┌───┐┌───┐     »
# q3_0: ┤ H ├┤ S ├┤ H ├──■──┤ X ├┤ X ├┤ S ├┤ H ├───────■──┤ X ├┤ H ├┤ S ├─────»
#       ├───┤├───┤├───┤┌─┴─┐└─┬─┘├───┤├───┤├───┤┌───┐┌─┴─┐└─┬─┘├───┤├───┤┌───┐»
# q3_1: ┤ X ├┤ H ├┤ S ├┤ X ├──■──┤ H ├┤ X ├┤ H ├┤ S ├┤ X ├──■──┤ H ├┤ S ├┤ X ├»
#       └───┘└───┘└───┘└───┘     └───┘└───┘└───┘└───┘└───┘     └───┘└───┘└───┘»
# «
# «q3_0: ─────
# «      ┌───┐
# «q3_1: ┤ H ├
# «      └───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('cx', 2) cx, [] to
# global phase: 3π/4
#       ┌─────────┐   ┌───┐   ┌─────────┐     ┌───┐   ┌───┐   ┌───┐┌─────────┐»
# q3_0: ┤ U2(0,π) ├───┤ S ├───┤ U2(0,π) ├──■──┤ X ├───┤ X ├───┤ S ├┤ U2(0,π) ├»
#       └──┬───┬──┘┌──┴───┴──┐└──┬───┬──┘┌─┴─┐└─┬─┘┌──┴───┴──┐├───┤├─────────┤»
# q3_1: ───┤ X ├───┤ U2(0,π) ├───┤ S ├───┤ X ├──■──┤ U2(0,π) ├┤ X ├┤ U2(0,π) ├»
#          └───┘   └─────────┘   └───┘   └───┘     └─────────┘└───┘└─────────┘»
# «                ┌───┐┌─────────┐┌───┐
# «q3_0: ───────■──┤ X ├┤ U2(0,π) ├┤ S ├────────────────
# «      ┌───┐┌─┴─┐└─┬─┘├─────────┤├───┤┌───┐┌─────────┐
# «q3_1: ┤ S ├┤ X ├──■──┤ U2(0,π) ├┤ S ├┤ X ├┤ U2(0,π) ├
# «      └───┘└───┘     └─────────┘└───┘└───┘└─────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: cx/2 [] =>
#
# q_0: ──────■──────
#      ┌───┐ │ ┌───┐
# q_1: ┤ H ├─■─┤ H ├
#      └───┘   └───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('cx', 2) cx, [] from
# global phase: 3π/4
#       ┌─────────┐   ┌───┐   ┌─────────┐     ┌───┐   ┌───┐   ┌───┐┌─────────┐»
# q3_0: ┤ U2(0,π) ├───┤ S ├───┤ U2(0,π) ├──■──┤ X ├───┤ X ├───┤ S ├┤ U2(0,π) ├»
#       └──┬───┬──┘┌──┴───┴──┐└──┬───┬──┘┌─┴─┐└─┬─┘┌──┴───┴──┐├───┤├─────────┤»
# q3_1: ───┤ X ├───┤ U2(0,π) ├───┤ S ├───┤ X ├──■──┤ U2(0,π) ├┤ X ├┤ U2(0,π) ├»
#          └───┘   └─────────┘   └───┘   └───┘     └─────────┘└───┘└─────────┘»
# «                ┌───┐┌─────────┐┌───┐
# «q3_0: ───────■──┤ X ├┤ U2(0,π) ├┤ S ├────────────────
# «      ┌───┐┌─┴─┐└─┬─┘├─────────┤├───┤┌───┐┌─────────┐
# «q3_1: ┤ S ├┤ X ├──■──┤ U2(0,π) ├┤ S ├┤ X ├┤ U2(0,π) ├
# «      └───┘└───┘     └─────────┘└───┘└───┘└─────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('cx', 2) cx, [] to
# global phase: 3π/4
#       ┌─────────┐   ┌───┐   ┌─────────┐        ┌───┐      ┌───┐   ┌───┐»
# q3_0: ┤ U2(0,π) ├───┤ S ├───┤ U2(0,π) ├──────■─┤ H ├─■────┤ H ├───┤ X ├»
#       └──┬───┬──┘┌──┴───┴──┐└──┬───┬──┘┌───┐ │ ├───┤ │ ┌──┴───┴──┐├───┤»
# q3_1: ───┤ X ├───┤ U2(0,π) ├───┤ S ├───┤ H ├─■─┤ H ├─■─┤ U2(0,π) ├┤ X ├»
#          └───┘   └─────────┘   └───┘   └───┘   └───┘   └─────────┘└───┘»
# «         ┌───┐   ┌─────────┐        ┌───┐      ┌───┐   ┌─────────┐┌───┐»
# «q3_0: ───┤ S ├───┤ U2(0,π) ├──────■─┤ H ├─■────┤ H ├───┤ U2(0,π) ├┤ S ├»
# «      ┌──┴───┴──┐└──┬───┬──┘┌───┐ │ ├───┤ │ ┌──┴───┴──┐└──┬───┬──┘├───┤»
# «q3_1: ┤ U2(0,π) ├───┤ S ├───┤ H ├─■─┤ H ├─■─┤ U2(0,π) ├───┤ S ├───┤ X ├»
# «      └─────────┘   └───┘   └───┘   └───┘   └─────────┘   └───┘   └───┘»
# «
# «q3_0: ───────────
# «      ┌─────────┐
# «q3_1: ┤ U2(0,π) ├
# «      └─────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: rx/1 [Parameter(theta)] =>
#      ┌────────────┐
# q_0: ┤ R(theta,0) ├
#      └────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('rx', 1) rx, ['rx[0]'] from
#       ┌───────────┐
# q5_0: ┤ rx(rx[0]) ├
#       └───────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('rx', 1) rx, ['rx[0]'] to
#       ┌────────────┐
# q5_0: ┤ R(rx[0],0) ├
#       └────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: r/1 [Parameter(theta), Parameter(phi)] =>
#      ┌───────────────────────────────────────────────────────────┐
# q_0: ┤ U3(theta,phi - 1.5707963267949,1.5707963267949 - 1.0*phi) ├
#      └───────────────────────────────────────────────────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('rx', 1) rx, ['rx[0]'] from
#       ┌────────────┐
# q5_0: ┤ R(rx[0],0) ├
#       └────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('rx', 1) rx, ['rx[0]'] to
#       ┌────────────────────┐
# q5_0: ┤ U3(rx[0],-π/2,π/2) ├
#       └────────────────────┘
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation paths composed in 0.224s.
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation instructions replaced in 7.101s.
# INFO:qiskit.transpiler.runningpassmanager:Pass: BasisTranslator - 7433.75659 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: RemoveResetInZeroState - 23.98658 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 7.99656 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 118.93249 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CXCancellation - 82.95107 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 4.99821 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 63.96246 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CXCancellation - 73.95935 (ms)
# INFO:qiskit.compiler.transpile:Total Transpile Time - 9805.40228 (ms)
# DEBUG:qiskit.aqua.quantum_instance:==== Before transpiler ====
# DEBUG:qiskit.aqua.quantum_instance:Submitting 1 circuits.
# ============================================================================
# 0-th circuit: 81 qubits, 81 classical bits and 15552 operations with depth 970
# op_counts: OrderedDict([('cx', 9936), ('rz', 5211), ('rx', 243), ('h', 81), ('measure', 81), ('snapshot', 1)])
# ============================================================================
#
# DEBUG:qiskit.aqua.quantum_instance:====  After transpiler ====
# DEBUG:qiskit.aqua.quantum_instance:Submitting 1 circuits.
# ============================================================================
# 0-th circuit: 81 qubits, 81 classical bits and 15552 operations with depth 970
# op_counts: OrderedDict([('cx', 9936), ('u3', 5454), ('h', 81), ('measure', 81), ('snapshot', 1)])
# ============================================================================
#
# DEBUG:qiskit.aqua.operators.converters.circuit_sampler:Parameter conversion 2416.61954 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)

# %%
import qiskit
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.17.4', 'qiskit-aer': '0.8.2', 'qiskit-ignis': '0.6.0', 'qiskit-ibmq-provider': '0.14.0', 'qiskit-aqua': '0.9.2', 'qiskit': '0.27.0', 'qiskit-nature': '0.1.3', 'qiskit-finance': None, 'qiskit-optimization': '0.1.0', 'qiskit-machine-learning': None}
