# %% [markdown]
# # QAOA implementation on Quantum devices

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install qiskit-terra==0.16.2
# !{sys.executable} -m pip install qiskit-aer==0.7.3
# !{sys.executable} -m pip install qiskit-ignis==0.5.1
# !{sys.executable} -m pip install qiskit-ibmq-provider==0.11.1
# !{sys.executable} -m pip install qiskit-aqua==0.8.1
# !{sys.executable} -m pip install qiskit==0.23.3
# Out:
# Requirement already satisfied: qiskit-terra==0.16.2 in c:\users\admin\anaconda3\lib\site-packages (0.16.2)
# Requirement already satisfied: retworkx>=0.5.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2) (0.7.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2) (1.19.5)
# Requirement already satisfied: dill>=0.3 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2) (0.3.3)
# Requirement already satisfied: sympy>=1.3 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2) (1.7.1)
# Requirement already satisfied: ply>=3.10 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2) (3.11)
# Requirement already satisfied: psutil>=5 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2) (5.8.0)
# Requirement already satisfied: networkx>=2.2 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2) (2.5)
# Requirement already satisfied: scipy>=1.4 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2) (1.6.0)
# Requirement already satisfied: fastjsonschema>=2.10 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2) (2.14.5)
# Requirement already satisfied: python-constraint>=1.4 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2) (1.4.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2) (2.8.1)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2) (3.2.0)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra==0.16.2) (41.4.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra==0.16.2) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra==0.16.2) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra==0.16.2) (1.15.0)
# Error processing line 7 of C:\Users\Admin\Anaconda3\lib\site-packages\pywin32.pth:
#
#   Traceback (most recent call last):
#     File "C:\Users\Admin\Anaconda3\lib\site.py", line 168, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
# Remainder of file ignored
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# Requirement already satisfied: importlib-metadata in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra==0.16.2) (3.4.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\admin\anaconda3\lib\site-packages (from networkx>=2.2->qiskit-terra==0.16.2) (4.4.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\admin\anaconda3\lib\site-packages (from sympy>=1.3->qiskit-terra==0.16.2) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\admin\anaconda3\lib\site-packages (from importlib-metadata->jsonschema>=2.6->qiskit-terra==0.16.2) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\admin\anaconda3\lib\site-packages (from importlib-metadata->jsonschema>=2.6->qiskit-terra==0.16.2) (3.4.0)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# Requirement already satisfied: qiskit-aer==0.7.3 in c:\users\admin\anaconda3\lib\site-packages (0.7.3)
# Requirement already satisfied: cython>=0.27.1 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aer==0.7.3) (0.29.21)
# Requirement already satisfied: qiskit-terra>=0.12.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aer==0.7.3) (0.16.2)
# Requirement already satisfied: pybind11>=2.4 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aer==0.7.3) (2.6.2)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aer==0.7.3) (1.19.5)
# Requirement already satisfied: scipy>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aer==0.7.3) (1.6.0)
# Requirement already satisfied: python-constraint>=1.4 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (1.4.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (1.7.1)
# Requirement already satisfied: dill>=0.3 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (0.3.3)
# Requirement already satisfied: ply>=3.10 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (3.11)
# Requirement already satisfied: networkx>=2.2 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (2.5)
# Requirement already satisfied: psutil>=5 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (5.8.0)
# Requirement already satisfied: retworkx>=0.5.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (0.7.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (3.2.0)
# Requirement already satisfied: fastjsonschema>=2.10 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (2.14.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (2.8.1)
# Error processing line 7 of C:\Users\Admin\Anaconda3\lib\site-packages\pywin32.pth:
#
#   Traceback (most recent call last):
#     File "C:\Users\Admin\Anaconda3\lib\site.py", line 168, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
# Remainder of file ignored
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# Requirement already satisfied: importlib-metadata in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (3.4.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (0.17.3)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (20.3.0)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (41.4.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\admin\anaconda3\lib\site-packages (from networkx>=2.2->qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (4.4.2)
# Requirement already satisfied: mpmath>=0.19 in c:\users\admin\anaconda3\lib\site-packages (from sympy>=1.3->qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (1.1.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\admin\anaconda3\lib\site-packages (from importlib-metadata->jsonschema>=2.6->qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\admin\anaconda3\lib\site-packages (from importlib-metadata->jsonschema>=2.6->qiskit-terra>=0.12.0->qiskit-aer==0.7.3) (3.7.4.3)
# Requirement already satisfied: qiskit-ignis==0.5.1 in c:\users\admin\anaconda3\lib\site-packages (0.5.1)
# Requirement already satisfied: numpy>=1.13 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-ignis==0.5.1) (1.19.5)
# Requirement already satisfied: scikit-learn>=0.17 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-ignis==0.5.1) (0.24.1)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-ignis==0.5.1) (41.4.0)
# Requirement already satisfied: scipy!=0.19.1,>=0.19 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-ignis==0.5.1) (1.6.0)
# Requirement already satisfied: qiskit-terra>=0.13.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-ignis==0.5.1) (0.16.2)
# Requirement already satisfied: sympy>=1.3 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (1.7.1)
# Requirement already satisfied: fastjsonschema>=2.10 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (2.14.5)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (2.8.1)
# Requirement already satisfied: networkx>=2.2 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (2.5)
# Requirement already satisfied: python-constraint>=1.4 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (1.4.0)
# Requirement already satisfied: ply>=3.10 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (3.11)
# Requirement already satisfied: dill>=0.3 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (0.3.3)
# Requirement already satisfied: psutil>=5 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (5.8.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (3.2.0)
# Requirement already satisfied: retworkx>=0.5.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (0.7.2)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (20.3.0)
# Requirement already satisfied: importlib-metadata in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (3.4.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (0.17.3)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\admin\anaconda3\lib\site-packages (from networkx>=2.2->qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (4.4.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn>=0.17->qiskit-ignis==0.5.1) (1.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn>=0.17->qiskit-ignis==0.5.1) (2.1.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\admin\anaconda3\lib\site-packages (from sympy>=1.3->qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (1.1.0)
# Requirement already satisfied: zipp>=0.5 in c:\users\admin\anaconda3\lib\site-packages (from importlib-metadata->jsonschema>=2.6->qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\admin\anaconda3\lib\site-packages (from importlib-metadata->jsonschema>=2.6->qiskit-terra>=0.13.0->qiskit-ignis==0.5.1) (3.7.4.3)
# Error processing line 7 of C:\Users\Admin\Anaconda3\lib\site-packages\pywin32.pth:
#
#   Traceback (most recent call last):
#     File "C:\Users\Admin\Anaconda3\lib\site.py", line 168, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
# Remainder of file ignored
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# Requirement already satisfied: qiskit-ibmq-provider==0.11.1 in c:\users\admin\anaconda3\lib\site-packages (0.11.1)
# Requirement already satisfied: nest-asyncio!=1.1.0,>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.11.1) (1.5.1)
# Requirement already satisfied: numpy>=1.13 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.11.1) (1.19.5)
# Requirement already satisfied: websockets>=8 in c:\users\admin\appdata\roaming\python\python37\site-packages (from qiskit-ibmq-provider==0.11.1) (8.1)
# Requirement already satisfied: requests>=2.19 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.11.1) (2.25.1)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.11.1) (1.26.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.11.1) (2.8.1)
# Requirement already satisfied: qiskit-terra>=0.15 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.11.1) (0.16.2)
# Requirement already satisfied: requests-ntlm>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.11.1) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.8.0->qiskit-ibmq-provider==0.11.1) (1.15.0)
# Requirement already satisfied: retworkx>=0.5.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (0.7.2)
# Requirement already satisfied: psutil>=5 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (5.8.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (3.2.0)
# Requirement already satisfied: dill>=0.3 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (0.3.3)
# Requirement already satisfied: fastjsonschema>=2.10 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (2.14.5)
# Requirement already satisfied: networkx>=2.2 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (2.5)
# Requirement already satisfied: sympy>=1.3 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (1.7.1)
# Error processing line 7 of C:\Users\Admin\Anaconda3\lib\site-packages\pywin32.pth:
#
#   Traceback (most recent call last):
#     File "C:\Users\Admin\Anaconda3\lib\site.py", line 168, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
# Remainder of file ignored
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# Requirement already satisfied: scipy>=1.4 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (1.6.0)
# Requirement already satisfied: python-constraint>=1.4 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (1.4.0)
# Requirement already satisfied: ply>=3.10 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (3.11)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (41.4.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (20.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (0.17.3)
# Requirement already satisfied: importlib-metadata in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (3.4.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\admin\anaconda3\lib\site-packages (from networkx>=2.2->qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (4.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.11.1) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.11.1) (2.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.11.1) (3.0.4)
# Requirement already satisfied: ntlm-auth>=1.0.2 in c:\users\admin\anaconda3\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.11.1) (1.5.0)
# Requirement already satisfied: cryptography>=1.3 in c:\users\admin\anaconda3\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.11.1) (3.3.1)
# Requirement already satisfied: cffi>=1.12 in c:\users\admin\anaconda3\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.11.1) (1.14.4)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.11.1) (2.20)
# Requirement already satisfied: mpmath>=0.19 in c:\users\admin\anaconda3\lib\site-packages (from sympy>=1.3->qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (1.1.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\admin\anaconda3\lib\site-packages (from importlib-metadata->jsonschema>=2.6->qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\admin\anaconda3\lib\site-packages (from importlib-metadata->jsonschema>=2.6->qiskit-terra>=0.15->qiskit-ibmq-provider==0.11.1) (3.4.0)
# Requirement already satisfied: qiskit-aqua==0.8.1 in c:\users\admin\anaconda3\lib\site-packages (0.8.1)
# Requirement already satisfied: dlx in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1) (1.0.4)
# Requirement already satisfied: qiskit-terra>=0.16.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1) (0.16.2)
# Requirement already satisfied: scipy>=1.4 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1) (1.6.0)
# Requirement already satisfied: docplex in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1) (2.19.202)
# Requirement already satisfied: h5py in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1) (3.1.0)
# Requirement already satisfied: sympy>=1.3 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1) (1.7.1)
# Requirement already satisfied: retworkx>=0.5.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1) (0.7.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1) (1.19.5)
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1) (1.2.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1) (0.24.1)
# Requirement already satisfied: quandl in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1) (3.6.0)
# Requirement already satisfied: fastdtw in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1) (0.3.4)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1) (41.4.0)
# Requirement already satisfied: psutil>=5 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1) (5.8.0)
# Requirement already satisfied: qiskit-ignis>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1) (0.5.1)
# Requirement already satisfied: yfinance in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1) (0.1.55)
# Requirement already satisfied: python-constraint>=1.4 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.16.0->qiskit-aqua==0.8.1) (1.4.0)
# Requirement already satisfied: dill>=0.3 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.16.0->qiskit-aqua==0.8.1) (0.3.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.16.0->qiskit-aqua==0.8.1) (2.8.1)
# Requirement already satisfied: fastjsonschema>=2.10 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.16.0->qiskit-aqua==0.8.1) (2.14.5)
# Requirement already satisfied: networkx>=2.2 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.16.0->qiskit-aqua==0.8.1) (2.5)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.16.0->qiskit-aqua==0.8.1) (3.2.0)
# Requirement already satisfied: ply>=3.10 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra>=0.16.0->qiskit-aqua==0.8.1) (3.11)
# Requirement already satisfied: importlib-metadata in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra>=0.16.0->qiskit-aqua==0.8.1) (3.4.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra>=0.16.0->qiskit-aqua==0.8.1) (0.17.3)
# Requirement already satisfied: six>=1.11.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra>=0.16.0->qiskit-aqua==0.8.1) (1.15.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra>=0.16.0->qiskit-aqua==0.8.1) (20.3.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\admin\anaconda3\lib\site-packages (from networkx>=2.2->qiskit-terra>=0.16.0->qiskit-aqua==0.8.1) (4.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.8.1) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.8.1) (1.0.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\admin\anaconda3\lib\site-packages (from sympy>=1.3->qiskit-aqua==0.8.1) (1.1.0)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (from docplex->qiskit-aqua==0.8.1) (2.25.1)
# Requirement already satisfied: cached-property in c:\users\admin\anaconda3\lib\site-packages (from h5py->qiskit-aqua==0.8.1) (1.5.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\admin\anaconda3\lib\site-packages (from importlib-metadata->jsonschema>=2.6->qiskit-terra>=0.16.0->qiskit-aqua==0.8.1) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\admin\anaconda3\lib\site-packages (from importlib-metadata->jsonschema>=2.6->qiskit-terra>=0.16.0->qiskit-aqua==0.8.1) (3.7.4.3)
# Requirement already satisfied: pytz>=2017.3 in c:\users\admin\anaconda3\lib\site-packages (from pandas->qiskit-aqua==0.8.1) (2020.5)
# Requirement already satisfied: inflection>=0.3.1 in c:\users\admin\anaconda3\lib\site-packages (from quandl->qiskit-aqua==0.8.1) (0.5.1)
# Requirement already satisfied: more-itertools in c:\users\admin\anaconda3\lib\site-packages (from quandl->qiskit-aqua==0.8.1) (8.6.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests->docplex->qiskit-aqua==0.8.1) (2.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests->docplex->qiskit-aqua==0.8.1) (1.26.3)
# Error processing line 7 of C:\Users\Admin\Anaconda3\lib\site-packages\pywin32.pth:
#
#   Traceback (most recent call last):
#     File "C:\Users\Admin\Anaconda3\lib\site.py", line 168, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
# Remainder of file ignored
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\admin\anaconda3\lib\site-packages (from requests->docplex->qiskit-aqua==0.8.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests->docplex->qiskit-aqua==0.8.1) (2020.12.5)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\admin\appdata\roaming\python\python37\site-packages (from yfinance->qiskit-aqua==0.8.1) (0.0.9)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\admin\anaconda3\lib\site-packages (from yfinance->qiskit-aqua==0.8.1) (4.6.2)
# Requirement already satisfied: qiskit==0.23.3 in c:\users\admin\anaconda3\lib\site-packages (0.23.3)
# Requirement already satisfied: qiskit-ignis==0.5.1 in c:\users\admin\anaconda3\lib\site-packages (from qiskit==0.23.3) (0.5.1)
# Requirement already satisfied: qiskit-aqua==0.8.1 in c:\users\admin\anaconda3\lib\site-packages (from qiskit==0.23.3) (0.8.1)
# Requirement already satisfied: qiskit-terra==0.16.2 in c:\users\admin\anaconda3\lib\site-packages (from qiskit==0.23.3) (0.16.2)
# Requirement already satisfied: qiskit-aer==0.7.3 in c:\users\admin\anaconda3\lib\site-packages (from qiskit==0.23.3) (0.7.3)
# Requirement already satisfied: qiskit-ibmq-provider==0.11.1 in c:\users\admin\anaconda3\lib\site-packages (from qiskit==0.23.3) (0.11.1)
# Requirement already satisfied: scipy>=1.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aer==0.7.3->qiskit==0.23.3) (1.6.0)
# Requirement already satisfied: pybind11>=2.4 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aer==0.7.3->qiskit==0.23.3) (2.6.2)
# Requirement already satisfied: numpy>=1.16.3 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aer==0.7.3->qiskit==0.23.3) (1.19.5)
# Requirement already satisfied: cython>=0.27.1 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aer==0.7.3->qiskit==0.23.3) (0.29.21)
# Requirement already satisfied: dlx in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1->qiskit==0.23.3) (1.0.4)
# Requirement already satisfied: yfinance in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1->qiskit==0.23.3) (0.1.55)
# Requirement already satisfied: psutil>=5 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1->qiskit==0.23.3) (5.8.0)
# Requirement already satisfied: fastdtw in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1->qiskit==0.23.3) (0.3.4)
# Requirement already satisfied: h5py in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1->qiskit==0.23.3) (3.1.0)
# Requirement already satisfied: setuptools>=40.1.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1->qiskit==0.23.3) (41.4.0)
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1->qiskit==0.23.3) (1.2.1)
# Requirement already satisfied: retworkx>=0.5.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1->qiskit==0.23.3) (0.7.2)
# Requirement already satisfied: docplex in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1->qiskit==0.23.3) (2.19.202)
# Requirement already satisfied: sympy>=1.3 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1->qiskit==0.23.3) (1.7.1)
# Requirement already satisfied: quandl in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1->qiskit==0.23.3) (3.6.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-aqua==0.8.1->qiskit==0.23.3) (0.24.1)
# Requirement already satisfied: nest-asyncio!=1.1.0,>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.11.1->qiskit==0.23.3) (1.5.1)
# Requirement already satisfied: requests>=2.19 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.11.1->qiskit==0.23.3) (2.25.1)
# Requirement already satisfied: websockets>=8 in c:\users\admin\appdata\roaming\python\python37\site-packages (from qiskit-ibmq-provider==0.11.1->qiskit==0.23.3) (8.1)
# Requirement already satisfied: urllib3>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.11.1->qiskit==0.23.3) (1.26.3)
# Requirement already satisfied: requests-ntlm>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.11.1->qiskit==0.23.3) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.0 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-ibmq-provider==0.11.1->qiskit==0.23.3) (2.8.1)
# Requirement already satisfied: fastjsonschema>=2.10 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2->qiskit==0.23.3) (2.14.5)
# Requirement already satisfied: ply>=3.10 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2->qiskit==0.23.3) (3.11)
# Requirement already satisfied: networkx>=2.2 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2->qiskit==0.23.3) (2.5)
# Requirement already satisfied: python-constraint>=1.4 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2->qiskit==0.23.3) (1.4.0)
# Requirement already satisfied: dill>=0.3 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2->qiskit==0.23.3) (0.3.3)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\admin\anaconda3\lib\site-packages (from qiskit-terra==0.16.2->qiskit==0.23.3) (3.2.0)
# Requirement already satisfied: six>=1.11.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra==0.16.2->qiskit==0.23.3) (1.15.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra==0.16.2->qiskit==0.23.3) (0.17.3)
# Requirement already satisfied: importlib-metadata in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra==0.16.2->qiskit==0.23.3) (3.4.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\admin\anaconda3\lib\site-packages (from jsonschema>=2.6->qiskit-terra==0.16.2->qiskit==0.23.3) (20.3.0)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\admin\anaconda3\lib\site-packages (from networkx>=2.2->qiskit-terra==0.16.2->qiskit==0.23.3) (4.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.11.1->qiskit==0.23.3) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.11.1->qiskit==0.23.3) (2.8)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.19->qiskit-ibmq-provider==0.11.1->qiskit==0.23.3) (3.0.4)
# Requirement already satisfied: cryptography>=1.3 in c:\users\admin\anaconda3\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.11.1->qiskit==0.23.3) (3.3.1)
# Requirement already satisfied: ntlm-auth>=1.0.2 in c:\users\admin\anaconda3\lib\site-packages (from requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.11.1->qiskit==0.23.3) (1.5.0)
# Requirement already satisfied: cffi>=1.12 in c:\users\admin\anaconda3\lib\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.11.1->qiskit==0.23.3) (1.14.4)
# Requirement already satisfied: pycparser in c:\users\admin\anaconda3\lib\site-packages (from cffi>=1.12->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibmq-provider==0.11.1->qiskit==0.23.3) (2.20)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.8.1->qiskit==0.23.3) (2.1.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn>=0.20.0->qiskit-aqua==0.8.1->qiskit==0.23.3) (1.0.0)
# Requirement already satisfied: mpmath>=0.19 in c:\users\admin\anaconda3\lib\site-packages (from sympy>=1.3->qiskit-aqua==0.8.1->qiskit==0.23.3) (1.1.0)
# Requirement already satisfied: cached-property in c:\users\admin\anaconda3\lib\site-packages (from h5py->qiskit-aqua==0.8.1->qiskit==0.23.3) (1.5.2)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\admin\anaconda3\lib\site-packages (from importlib-metadata->jsonschema>=2.6->qiskit-terra==0.16.2->qiskit==0.23.3) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in c:\users\admin\anaconda3\lib\site-packages (from importlib-metadata->jsonschema>=2.6->qiskit-terra==0.16.2->qiskit==0.23.3) (3.4.0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\admin\anaconda3\lib\site-packages (from pandas->qiskit-aqua==0.8.1->qiskit==0.23.3) (2020.5)
# Requirement already satisfied: inflection>=0.3.1 in c:\users\admin\anaconda3\lib\site-packages (from quandl->qiskit-aqua==0.8.1->qiskit==0.23.3) (0.5.1)
# Requirement already satisfied: more-itertools in c:\users\admin\anaconda3\lib\site-packages (from quandl->qiskit-aqua==0.8.1->qiskit==0.23.3) (8.6.0)
# Requirement already satisfied: lxml>=4.5.1 in c:\users\admin\anaconda3\lib\site-packages (from yfinance->qiskit-aqua==0.8.1->qiskit==0.23.3) (4.6.2)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\admin\appdata\roaming\python\python37\site-packages (from yfinance->qiskit-aqua==0.8.1->qiskit==0.23.3) (0.0.9)
# Error processing line 7 of C:\Users\Admin\Anaconda3\lib\site-packages\pywin32.pth:
#
#   Traceback (most recent call last):
#     File "C:\Users\Admin\Anaconda3\lib\site.py", line 168, in addpackage
#       exec(line)
#     File "<string>", line 1, in <module>
#   ModuleNotFoundError: No module named 'pywin32_bootstrap'
#
# Remainder of file ignored
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -yrsistent (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -iskit-terra (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -illow (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ffi (c:\users\admin\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\admin\anaconda3\lib\site-packages)

# %%
import warnings
help(warnings.filterwarnings)
# Out:
# Help on function filterwarnings in module warnings:
#
# filterwarnings(action, message='', category=<class 'Warning'>, module='', lineno=0, append=False)
#     Insert an entry into the list of warnings filters (at the front).
#
#     'action' -- one of "error", "ignore", "always", "default", "module",
#                 or "once"
#     'message' -- a regex that the warning message must match
#     'category' -- a class that the warning must be a subclass of
#     'module' -- a regex that the module name must match
#     'lineno' -- an integer line number, 0 matches all warnings
#     'append' -- if true, append to the list of filters

# %%
#Initialisation cell
from docplex.mp.model import Model
from qiskit.providers.ibmq.managed import IBMQJobManager
import qiskit

from qiskit import BasicAer, Aer
from qiskit.aqua.algorithms import VQE, ExactEigensolver,NumPyEigensolver,QAOA
from qiskit.aqua.components.optimizers import SPSA, COBYLA,ADAM, L_BFGS_B
from qiskit.circuit.library import RealAmplitudes #(uses CX entangling) 
from qiskit.optimization.applications.ising.common import sample_most_likely
from qiskit.circuit.library import TwoLocal
#from qiskit.aqua.components.variational_forms import RY
from qiskit.aqua import QuantumInstance

from qiskit.optimization import QuadraticProgram
from qiskit.tools.visualization import plot_histogram
from qiskit.optimization.applications.ising import docplex
from qiskit.optimization.algorithms import MinimumEigenOptimizer,RecursiveMinimumEigenOptimizer

# setup aqua logging
import logging
from qiskit.aqua import set_qiskit_aqua_logging
# set_qiskit_aqua_logging(logging.DEBUG)  # choose INFO, DEBUG to see the log

# useful additional packages 
import matplotlib.pyplot as plt
import matplotlib.axes as axes
# %matplotlib inline
import numpy as np
import math
import networkx as nx
import pandas as pd
from   matplotlib import cm
from   matplotlib.ticker import LinearLocator, FormatStrFormatter
# %config InlineBackend.figure_format = 'svg' # Makes the images look nice

# importing Qiskit
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, execute
from qiskit.providers.ibmq      import least_busy
from qiskit.tools.monitor       import job_monitor
from qiskit.providers.aer import QasmSimulator

# %% [markdown]
# Important prelim functions

# %%
def CSVtoNumpyArray(rawdata):
    """
    Input: 
    rawdata = a csv file (insert name as a string)

    Output:
    two numpy matrices in a tuple
    """
    data = pd.read_csv(rawdata)  #Reads the data in as a pandas object
    c = data.columns
    column = int(c[0])
    final_data1 = data.iloc[:column,:].values  #Sets data into a series of numpy arrays of strings
    final_data2 = data.iloc[column:,:].values  #1 is for the first matrix(loc) and 2 is for the second(flow)
    

    #Forms the matrix as a numpy array (easier to work with) instead of an list of lists of strings
    def string_to_integers(final_data):
        matrix = []
        for j in range(column):
            string = final_data[j][0]
            string2 = string.split(" ")
            emptyarray = []
            for i in string2:
                if i != '':
                    emptyarray.append(int(i))
            matrix.append(emptyarray)
        npmatrix = np.array(matrix) 
        return npmatrix
    return string_to_integers(final_data1),string_to_integers(final_data2)

# %%
def qap_value(z, MatrixLoc, MatrixFlow):
    """Compute the TSP value of a solution.
    Args:
        z (list[int]): list of allocations
        MatrixLoc (numpy array): matrix of distances
        MatrixFlow (numpy array): matrix of flow
    Returns:
        float: value of the QAP
    """
    matrix_length = len(MatrixLoc)
    x = np.reshape(z, (matrix_length,matrix_length)).astype(int)
    
    total = 0
    for i in range(matrix_length):
        for j in range(matrix_length):
            for k in range(matrix_length):
                for p in range(matrix_length):
                        total += MatrixLoc[i,j]* MatrixFlow[k,p]*x[i,k]*x[j,p]
    
    return total

# %% [markdown]
# Feasibility functions

# %%
def qap_feasible(x):
    """Check whether a solution is feasible or not.

    Args:
        x (numpy.ndarray) : binary string as numpy array.

    Returns:
        bool: feasible or not.
    """
    n = int(np.sqrt(len(x)))
    y = np.reshape(x, (n,n)).astype(int)
   
    for i in range(n):
        if sum(y[i, p] for p in range(n)) != 1:
            return False
    for p__ in range(n):
        if sum(y[i, p__] for i in range(n)) != 1:
            return False
    return True

# %%
def choose_best_feasible(eigenstates):
    """
    Input:
    eigenstates = dictionary
    
    Output:
    feasible binary 1D numpyarray
    probability of this answer
    
    """
    bestinarray = sorted(eigenstates.items(), key=lambda item: item[1])[::-1]
    feasible = False
    counter = 0
    total = sum(eigenstates.values())
    
    feasible=False
    while feasible==False and counter<len(bestinarray):
        #string to array
        bestasint = np.array([0])
        for i in bestinarray[counter][0]:
            bestasint = np.hstack((bestasint, int(i)))
        feasible = qap_feasible(bestasint[1:])
        frequency = bestinarray[counter][1]
        counter += 1
        
    if feasible == False:
        return feasible
    else:
        return bestasint[1:], frequency/total

# %% [markdown]
# ## IBM device loading

# %%
from qiskit import IBMQ

# Load account from disk
IBMQ.load_account()
IBMQ.providers()
# Out:
# C:\Users\Admin\Anaconda3\lib\site-packages\qiskit\providers\ibmq\ibmqfactory.py:192: UserWarning: Timestamps in IBMQ backend properties, jobs, and job results are all now in local time instead of UTC.
#   warnings.warn('Timestamps in IBMQ backend properties, jobs, and job results '
# [<AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>,
#  <AccountProvider for IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <AccountProvider for IBMQ(hub='ibm-q-wits', group='internal', project='wits-eie')>]

# %%
provider = IBMQ.get_provider(hub='ibm-q-wits',project='physics')
provider.backends()
# Out:
# [<IBMQSimulator('ibmq_qasm_simulator') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQBackend('ibmqx2') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQBackend('ibmq_16_melbourne') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQBackend('ibmq_armonk') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQBackend('ibmq_athens') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQBackend('ibmq_rome') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQBackend('ibmq_toronto') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQBackend('ibmq_santiago') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQBackend('ibmq_bogota') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQBackend('ibmq_manhattan') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQBackend('ibmq_casablanca') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQBackend('ibmq_sydney') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQBackend('ibmq_lima') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQBackend('ibmq_belem') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQBackend('ibmq_quito') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQBackend('ibmq_guadalupe') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQSimulator('simulator_statevector') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQSimulator('simulator_mps') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQSimulator('simulator_extended_stabilizer') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>,
#  <IBMQSimulator('simulator_stabilizer') from IBMQ(hub='ibm-q-wits', group='internal', project='physics')>]

# %% [markdown]
# ## The QAOA function

# %%
def testing_quantum(ins, iterations, backend, optimal_point, trials):
    """
    Input:
    ins: name of instance
    iterations
    backend
    optimal_point
    trials
    
    Output:
    outmatrix : [soln,result time,eigenvector,number of spsa trials]
    """
    
    #get matrix
    datamatrix = CSVtoNumpyArray(ins)
    MatrixLoc = datamatrix[0]
    MatrixFlow = datamatrix[1]
    n = len(MatrixLoc)

    # Create an instance of a model and variables.
    thename = "qap" + str(n)
    mdl = Model(name=thename)
    x = {(i,p): mdl.binary_var(name='x_{0}_{1}'.format(i,p)) for i in range(n) for p in range(n)}

    # Object function
    qap_func = mdl.sum(MatrixLoc[i,j]* MatrixFlow[k,p]*x[i,k]*x[j,p] for i in range(n) for j in range(n) for p in range(n) for k in range(n))
    mdl.minimize(qap_func)

    # Constraints
    for i in range(n):
        mdl.add_constraint(mdl.sum(x[(i,p)] for p in range(n)) == 1)
    for p in range(n):
        mdl.add_constraint(mdl.sum(x[(i,p)] for i in range(n)) == 1)
    print(mdl.export_to_string())
    qubitOp_docplex, offset_docplex = docplex.get_operator(mdl) #potential error

    #QAOA
    machinesolutions = []
    rmachinesolutions = []
    seed = 10598
    mod = QuadraticProgram()
    mod.from_docplex(mdl)
    #print(mod.export_as_lp_string())

    #30 trials
    file = open("thirty_trials-" + str(backend) + "-" + str(ins) ,"w")
    file.write("value,   feasible,   frequency, time, iteration" + "\n")
    ans = np.zeros(5)
    for i in range(trials):
        #try:
        spsa = SPSA(maxiter=iterations)
        #Backend = Aer.get_backend('qasm_simulator')
        backend = provider.get_backend(backend)
        quantum_instance = QuantumInstance(backend=backend,seed_simulator=seed,
                                           seed_transpiler=seed, skip_qobj_validation = False, shots = 1024)

        qaoa = QAOA(qubitOp_docplex,optimizer=spsa, p=3,include_custom=True,initial_point = optimal_point)
        result = qaoa.run(quantum_instance)
        print(result['optimal_point'])
        #print('QAOA vector:', result['eigenstate'])
        print('QAOA time:', result['optimizer_time'])
        print('QAOA QAP objective:', result['eigenvalue'] + offset_docplex)

        n = len(list(result['eigenstate'].values()))
        solution = np.hstack((np.array(list(result['eigenstate'].values())).reshape(n,1),np.array(list(result['eigenstate'].keys())).reshape(n,1)))
        print(solution)
        for r in solution:
            file.write(str(qap_value(np.array(list(r[1])),MatrixFlow,MatrixLoc)) + "," + str(qap_feasible(np.array(list(r[1])))) + "," + str(r[0]) + ","+ str(result['optimizer_time']) + "," + str(i) + "\n")
            ans = np.vstack((ans,np.array([qap_value(np.array(list(r[1])),MatrixFlow,MatrixLoc),qap_feasible(np.array(list(r[1]))),float(r[0]),result['optimizer_time'],i])))
        #except:
            #file.write("An error occurred on iteration " + str(i) + " of the 30 trials")
            #print("AN ERROR OCCURRED ON ITERATION" + str(i) + " of the 30 trials")
            #ans = np.vstack((ans,np.array([math.inf,False,0,np.nan,i])))
        print("Iteration "+ str(i) + " is complete.")
    file.close()
    return ans[1:]

# %%
def read_optimal(ins):
    data = pd.read_csv("initial_point-" + str(ins),header = None)
    n = len(data[0]) - 1
    ans = []
    data[0][0] = data[0][0][1:]
    data[0][n] = data[0][n][:-1]
    for i in data[0]:
        r = i.split(" ")
        for t in r:
            if t!='':
                ans.append(float(t))
    return np.array(ans)

# %% [markdown]
# ## The results cells

# %%
ins = "made3.csv"
iterations = 100
import logging
logging.basicConfig(level=logging.DEBUG) # log the steps of the algorithm and results
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
backend = 'ibmq_manhattan'
optimal_point = read_optimal(ins)
ans = testing_quantum(ins, iterations, backend, optimal_point, 30)

# %%
qiskit.__qiskit_version__
# Out:
# {'qiskit-terra': '0.16.2',
#  'qiskit-aer': '0.7.3',
#  'qiskit-ignis': '0.5.1',
#  'qiskit-ibmq-provider': '0.11.1',
#  'qiskit-aqua': '0.8.1',
#  'qiskit': '0.23.3'}
