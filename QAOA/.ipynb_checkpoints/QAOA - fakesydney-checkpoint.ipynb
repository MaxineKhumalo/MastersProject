# %% [markdown]
# # QAOA implementation on Quantum devices

# %%
#Initialisation cell
from docplex.mp.model import Model
from qiskit.providers.ibmq.managed import IBMQJobManager

from qiskit import BasicAer, Aer
from qiskit.aqua.algorithms import VQE, ExactEigensolver,NumPyEigensolver,QAOA
from qiskit.aqua.components.optimizers import SPSA, COBYLA,ADAM, L_BFGS_B
from qiskit.circuit.library import RealAmplitudes #(uses CX entangling) 
from qiskit.optimization.applications.ising.common import sample_most_likely
from qiskit.circuit.library import TwoLocal
#from qiskit.aqua.components.variational_forms import RY
from qiskit.aqua import QuantumInstance

from qiskit.optimization import QuadraticProgram
from qiskit.tools.visualization import plot_histogram
from qiskit.optimization.applications.ising import docplex
from qiskit.optimization.algorithms import MinimumEigenOptimizer,RecursiveMinimumEigenOptimizer

# setup aqua logging
import logging
from qiskit.aqua import set_qiskit_aqua_logging
# set_qiskit_aqua_logging(logging.DEBUG)  # choose INFO, DEBUG to see the log

# useful additional packages 
import matplotlib.pyplot as plt
import matplotlib.axes as axes
# %matplotlib inline
import numpy as np
import math
import networkx as nx
import pandas as pd
from   matplotlib import cm
from   matplotlib.ticker import LinearLocator, FormatStrFormatter
# %config InlineBackend.figure_format = 'svg' # Makes the images look nice

# importing Qiskit
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit, execute
from qiskit.providers.ibmq      import least_busy
from qiskit.tools.monitor       import job_monitor
from qiskit.providers.aer import QasmSimulator
# Out:
# DEBUG:matplotlib:(private) matplotlib data path: C:\Users\Admin\Anaconda3\lib\site-packages\matplotlib\mpl-data
# DEBUG:matplotlib:matplotlib data path: C:\Users\Admin\Anaconda3\lib\site-packages\matplotlib\mpl-data
# DEBUG:matplotlib:CONFIGDIR=C:\Users\Admin\.matplotlib
# DEBUG:matplotlib:matplotlib version 3.3.4
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is win32
# DEBUG:matplotlib:loaded modules: ['sys', 'builtins', '_frozen_importlib', '_imp', '_thread', '_warnings', '_weakref', 'zipimport', '_frozen_importlib_external', '_io', 'marshal', 'nt', 'winreg', 'encodings', 'codecs', '_codecs', 'encodings.aliases', 'encodings.utf_8', '_signal', '__main__', 'encodings.latin_1', 'io', 'abc', '_abc', '_bootlocale', '_locale', 'encodings.cp1252', 'site', 'os', 'stat', '_stat', 'ntpath', 'genericpath', 'os.path', '_collections_abc', '_sitebuiltins', 'types', 'importlib', 'importlib._bootstrap', 'importlib._bootstrap_external', 'warnings', 'importlib.util', 'importlib.abc', 'importlib.machinery', 'contextlib', 'collections', 'operator', '_operator', 'keyword', 'heapq', '_heapq', 'itertools', 'reprlib', '_collections', 'functools', '_functools', 'mpl_toolkits', 'traceback', 'linecache', 'tokenize', 're', 'enum', 'sre_compile', '_sre', 'sre_parse', 'sre_constants', 'copyreg', 'token', 'sphinxcontrib', 'zope', 'runpy', 'pkgutil', 'weakref', '_weakrefset', 'ipykernel', 'ipykernel._version', 'ipykernel.connect', 'json', 'json.decoder', 'json.scanner', '_json', 'json.encoder', 'subprocess', 'time', 'signal', 'errno', 'threading', 'msvcrt', '_winapi', 'IPython', 'IPython.core', 'IPython.core.getipython', 'IPython.core.release', 'IPython.core.application', 'atexit', 'copy', 'glob', 'fnmatch', 'posixpath', 'logging', 'collections.abc', 'string', '_string', 'shutil', 'zlib', 'bz2', '_compression', '_bz2', 'lzma', '_lzma', 'traitlets', 'traitlets.traitlets', 'ast', '_ast', 'inspect', 'dis', 'opcode', '_opcode', 'traitlets.utils', 'traitlets.utils.getargspec', 'traitlets.utils.importstring', 'traitlets.utils.sentinel', 'traitlets.utils.bunch', 'traitlets.utils.descriptions', 'traitlets.utils.decorators', 'traitlets._version', 'traitlets.config', 'traitlets.config.application', 'pprint', 'traitlets.config.configurable', 'traitlets.config.loader', 'argparse', 'gettext', 'locale', 'ipython_genutils', 'ipython_genutils._version', 'ipython_genutils.path', 'random', 'math', 'hashlib', '_hashlib', '_blake2', '_sha3', 'bisect', '_bisect', '_random', 'ipython_genutils.py3compat', 'ipython_genutils.encoding', 'platform', 'ipython_genutils.text', 'textwrap', 'IPython.core.crashhandler', 'IPython.core.ultratb', 'pydoc', 'urllib', 'urllib.parse', 'IPython.core.debugger', 'bdb', 'IPython.utils', 'IPython.utils.PyColorize', 'IPython.utils.coloransi', 'IPython.utils.ipstruct', 'IPython.utils.colorable', 'pygments', 'IPython.utils.py3compat', 'IPython.utils.encoding', 'IPython.core.excolors', 'IPython.testing', 'IPython.testing.skipdoctest', 'pdb', 'cmd', 'code', 'codeop', '__future__', 'IPython.core.display_trap', 'IPython.utils.path', 'IPython.utils.process', 'IPython.utils._process_win32', 'ctypes', '_ctypes', 'struct', '_struct', 'ctypes._endian', 'ctypes.wintypes', 'IPython.utils._process_common', 'shlex', 'IPython.utils.decorators', 'IPython.utils.data', 'IPython.utils.terminal', 'IPython.utils.sysinfo', 'IPython.utils._sysinfo', 'IPython.core.profiledir', 'IPython.paths', 'tempfile', 'IPython.utils.importstring', 'IPython.terminal', 'IPython.terminal.embed', 'IPython.core.compilerop', 'IPython.core.magic_arguments', 'IPython.core.error', 'IPython.utils.text', 'pathlib', 'IPython.core.magic', 'getopt', 'IPython.core.oinspect', 'typing', 'typing.io', 'typing.re', 'IPython.core.page', 'IPython.core.display', 'binascii', 'mimetypes', 'IPython.lib', 'IPython.lib.security', 'getpass', 'IPython.lib.pretty', 'datetime', '_datetime', 'IPython.utils.openpy', 'IPython.utils.dir2', 'IPython.utils.wildcard', 'pygments.lexers', 'pygments.lexers._mapping', 'pygments.modeline', 'pygments.plugin', 'pygments.util', 'pygments.lexers.python', 'pygments.lexer', 'pygments.filter', 'pygments.filters', 'pygments.token', 'pygments.regexopt', 'pygments.unistring', 'pygments.formatters', 'pygments.formatters._mapping', 'pygments.formatters.html', 'pygments.formatter', 'pygments.styles', 'IPython.core.inputtransformer2', 'decorator', 'IPython.core ...
# DEBUG:matplotlib:CACHEDIR=C:\Users\Admin\.matplotlib
# DEBUG:matplotlib.font_manager:Using fontManager instance from C:\Users\Admin\.matplotlib\fontlist-v330.json
# DEBUG:matplotlib.pyplot:Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# DEBUG:matplotlib.pyplot:Loaded backend module://ipykernel.pylab.backend_inline version unknown.
# DEBUG:matplotlib.pyplot:Loaded backend module://ipykernel.pylab.backend_inline version unknown.

# %% [markdown]
# Important prelim functions

# %%
def CSVtoNumpyArray(rawdata):
    """
    Input: 
    rawdata = a csv file (insert name as a string)

    Output:
    two numpy matrices in a tuple
    """
    data = pd.read_csv(rawdata)  #Reads the data in as a pandas object
    c = data.columns
    column = int(c[0])
    final_data1 = data.iloc[:column,:].values  #Sets data into a series of numpy arrays of strings
    final_data2 = data.iloc[column:,:].values  #1 is for the first matrix(loc) and 2 is for the second(flow)
    

    #Forms the matrix as a numpy array (easier to work with) instead of an list of lists of strings
    def string_to_integers(final_data):
        matrix = []
        for j in range(column):
            string = final_data[j][0]
            string2 = string.split(" ")
            emptyarray = []
            for i in string2:
                if i != '':
                    emptyarray.append(int(i))
            matrix.append(emptyarray)
        npmatrix = np.array(matrix) 
        return npmatrix
    return string_to_integers(final_data1),string_to_integers(final_data2)

# %%
def qap_value(z, MatrixLoc, MatrixFlow):
    """Compute the TSP value of a solution.
    Args:
        z (list[int]): list of allocations
        MatrixLoc (numpy array): matrix of distances
        MatrixFlow (numpy array): matrix of flow
    Returns:
        float: value of the QAP
    """
    matrix_length = len(MatrixLoc)
    x = np.reshape(z, (matrix_length,matrix_length)).astype(int)
    
    total = 0
    for i in range(matrix_length):
        for j in range(matrix_length):
            for k in range(matrix_length):
                for p in range(matrix_length):
                        total += MatrixLoc[i,j]* MatrixFlow[k,p]*x[i,k]*x[j,p]
    
    return total

# %% [markdown]
# Feasibility functions

# %%
def qap_feasible(x):
    """Check whether a solution is feasible or not.

    Args:
        x (numpy.ndarray) : binary string as numpy array.

    Returns:
        bool: feasible or not.
    """
    n = int(np.sqrt(len(x)))
    y = np.reshape(x, (n,n)).astype(int)
   
    for i in range(n):
        if sum(y[i, p] for p in range(n)) != 1:
            return False
    for p__ in range(n):
        if sum(y[i, p__] for i in range(n)) != 1:
            return False
    return True

# %%
def choose_best_feasible(eigenstates):
    """
    Input:
    eigenstates = dictionary
    
    Output:
    feasible binary 1D numpyarray
    probability of this answer
    
    """
    bestinarray = sorted(eigenstates.items(), key=lambda item: item[1])[::-1]
    feasible = False
    counter = 0
    total = sum(eigenstates.values())
    
    feasible=False
    while feasible==False and counter<len(bestinarray):
        #string to array
        bestasint = np.array([0])
        for i in bestinarray[counter][0]:
            bestasint = np.hstack((bestasint, int(i)))
        feasible = qap_feasible(bestasint[1:])
        frequency = bestinarray[counter][1]
        counter += 1
        
    if feasible == False:
        return feasible
    else:
        return bestasint[1:], frequency/total

# %% [markdown]
# ## IBM device loading

# %%
from qiskit.test.mock.backends import FakeBoeblingen
backend=FakeBoeblingen()
backend
# Out:
# DEBUG:qiskit.test.testing_options:{'skip_online': False, 'mock_online': False, 'run_slow': False, 'rec': False}
# <FakeBoeblingen('fake_boeblingen') from None()>

# %%
import qiskit.test.mock.backends
help(qiskit.test.mock.backends)
# Out:
# Help on package qiskit.test.mock.backends in qiskit.test.mock:
#
# NAME
#     qiskit.test.mock.backends - Mocked versions of real quantum backends.
#
# PACKAGE CONTENTS
#     almaden (package)
#     armonk (package)
#     athens (package)
#     boeblingen (package)
#     bogota (package)
#     burlington (package)
#     cambridge (package)
#     essex (package)
#     johannesburg (package)
#     london (package)
#     manhattan (package)
#     melbourne (package)
#     montreal (package)
#     ourense (package)
#     paris (package)
#     poughkeepsie (package)
#     rochester (package)
#     rome (package)
#     rueschlikon (package)
#     santiago (package)
#     singapore (package)
#     tenerife (package)
#     tokyo (package)
#     toronto (package)
#     valencia (package)
#     vigo (package)
#     yorktown (package)
#
# FILE
#     c:\users\admin\anaconda3\lib\site-packages\qiskit\test\mock\backends\__init__.py

# %% [markdown]
# ## The QAOA function

# %%
def testing_quantum(ins, iterations, backend, optimal_point, trials):
    """
    Input:
    ins: name of instance
    iterations
    backend
    optimal_point
    trials
    
    Output:
    outmatrix : [soln,result time,eigenvector,number of spsa trials]
    """
    
    #get matrix
    datamatrix = CSVtoNumpyArray(ins)
    MatrixLoc = datamatrix[0]
    MatrixFlow = datamatrix[1]
    n = len(MatrixLoc)

    # Create an instance of a model and variables.
    thename = "qap" + str(n)
    mdl = Model(name=thename)
    x = {(i,p): mdl.binary_var(name='x_{0}_{1}'.format(i,p)) for i in range(n) for p in range(n)}

    # Object function
    qap_func = mdl.sum(MatrixLoc[i,j]* MatrixFlow[k,p]*x[i,k]*x[j,p] for i in range(n) for j in range(n) for p in range(n) for k in range(n))
    mdl.minimize(qap_func)

    # Constraints
    for i in range(n):
        mdl.add_constraint(mdl.sum(x[(i,p)] for p in range(n)) == 1)
    for p in range(n):
        mdl.add_constraint(mdl.sum(x[(i,p)] for i in range(n)) == 1)
    print(mdl.export_to_string())
    qubitOp_docplex, offset_docplex = docplex.get_operator(mdl) #potential error

    #QAOA
    machinesolutions = []
    rmachinesolutions = []
    seed = 10598
    mod = QuadraticProgram()
    mod.from_docplex(mdl)
    #print(mod.export_as_lp_string())

    #30 trials
    file = open("thirty_trials-" + str(backend) + "-" + str(ins) ,"w")
    file.write("value,   feasible,   frequency, time, iteration" + "\n")
    ans = np.zeros(5)
    for i in range(trials):
        #try:
        spsa = SPSA(maxiter=iterations)
        #Backend = Aer.get_backend('qasm_simulator')
        Backend=FakeBoeblingen()
        quantum_instance = QuantumInstance(backend=Backend,seed_simulator=seed,
                                           seed_transpiler=seed, skip_qobj_validation = False, shots = 1024)

        qaoa = QAOA(qubitOp_docplex,optimizer=spsa, p=3,include_custom=True,initial_point = optimal_point)
        result = qaoa.run(quantum_instance)
        print(result['optimal_point'])
        #print('QAOA vector:', result['eigenstate'])
        print('QAOA time:', result['optimizer_time'])
        print('QAOA QAP objective:', result['eigenvalue'] + offset_docplex)

        n = len(list(result['eigenstate'].values()))
        solution = np.hstack((np.array(list(result['eigenstate'].values())).reshape(n,1),np.array(list(result['eigenstate'].keys())).reshape(n,1)))
        print(solution)
        for r in solution:
            file.write(str(qap_value(np.array(list(r[1])),MatrixFlow,MatrixLoc)) + "," + str(qap_feasible(np.array(list(r[1])))) + "," + str(r[0]) + ","+ str(result['optimizer_time']) + "," + str(i) + "\n")
            ans = np.vstack((ans,np.array([qap_value(np.array(list(r[1])),MatrixFlow,MatrixLoc),qap_feasible(np.array(list(r[1]))),float(r[0]),result['optimizer_time'],i])))
        #except:
            #file.write("An error occurred on iteration " + str(i) + " of the 30 trials")
            #print("AN ERROR OCCURRED ON ITERATION" + str(i) + " of the 30 trials")
            #ans = np.vstack((ans,np.array([math.inf,False,0,np.nan,i])))
        print("Iteration "+ str(i) + " is complete.")
    file.close()
    return ans[1:]

# %%
def read_optimal(ins):
    data = pd.read_csv("initial_point-" + str(ins),header = None)
    n = len(data[0]) - 1
    ans = []
    data[0][0] = data[0][0][1:]
    data[0][n] = data[0][n][:-1]
    for i in data[0]:
        r = i.split(" ")
        for t in r:
            if t!='':
                ans.append(float(t))
    return np.array(ans)

# %% [markdown]
# ## The results cells

# %%
ins = "made3.csv"
iterations = 1
import logging
logging.basicConfig(level=logging.DEBUG) # log the steps of the algorithm and results
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
backend = 'ifake_boeb'
optimal_point = read_optimal(ins)
ans = testing_quantum(ins, iterations, backend, optimal_point, 21)
# Out:
# INFO:qiskit.aqua.quantum_instance:
# Qiskit Terra version: 0.16.2
# Backend: 'fake_boeblingen (None)', with following setting:
# {'basis_gates': ['id', 'u1', 'u2', 'u3', 'cx'], 'coupling_map': [[0, 1], [1, 0], [1, 2], [1, 6], [2, 1], [2, 3], [3, 2], [3, 4], [3, 8], [4, 3], [5, 6], [5, 10], [6, 1], [6, 5], [6, 7], [7, 6], [7, 8], [7, 12], [8, 3], [8, 7], [8, 9], [9, 8], [9, 14], [10, 5], [10, 11], [11, 10], [11, 12], [11, 16], [12, 7], [12, 11], [12, 13], [13, 12], [13, 14], [13, 18], [14, 9], [14, 13], [15, 16], [16, 11], [16, 15], [16, 17], [17, 16], [17, 18], [18, 13], [18, 17], [18, 19], [19, 18]]}
# {'initial_layout': None, 'seed_transpiler': 10598, 'optimization_level': None}
# RunConfig(max_credits=10, seed_simulator=10598, shots=1024)
# {'timeout': None, 'wait': 5.0}
# {}
# {}
# Measurement mitigation: None
# INFO:qiskit.aqua.algorithms.minimum_eigen_solvers.vqe:
# ==================== Setting of QAOA ============================
# Algorithm: QAOA
# -- p: 3
# -- mixer_operator: None
# -- initial_state: None
# -- max_evals_grouped: 1
# -- circuit_sampler: None
# -- expectation: None
# -- user_valid_expectation: False
# -- include_custom: True
# -- expect_op: None
# -- operator: SummedOp([
#   588.0 * IIIIIZIZI,
#   -85173.0 * IIIIIIIZI,
#   -86572.5 * IIIIIZIII,
#   430.5 * IIIIIZZII,
#   -84303.0 * IIIIIIZII,
#   588.0 * IIIIZIIIZ,
#   -87203.0 * IIIIIIIIZ,
#   -84770.0 * IIIIZIIII,
#   63.0 * IIIIZIZII,
#   430.5 * IIIZIIIIZ,
#   -83997.5 * IIIZIIIII,
#   63.0 * IIIZIIIZI,
#   2660.0 * IIZIIIIZI,
#   -90161.5 * IIZIIIIII,
#   1947.5 * IIZIIIZII,
#   2660.0 * IZIIIIIIZ,
#   -87064.0 * IZIIIIIII,
#   285.0 * IZIIIIZII,
#   1947.5 * ZIIIIIIIZ,
#   -85736.5 * ZIIIIIIII,
#   285.0 * ZIIIIIIZI,
#   2296.0 * IIZIZIIII,
#   1681.0 * IIZZIIIII,
#   2296.0 * IZIIIZIII,
#   246.0 * IZIZIIIII,
#   1681.0 * ZIIIIZIII,
#   246.0 * ZIIIZIIII,
#   40788.5 * IIIIIIIZZ,
#   40788.5 * IIIIIIZIZ,
#   40788.5 * IIIIIIZZI,
#   40788.5 * IIIIZZIII,
#   40788.5 * IIIZIZIII,
#   40788.5 * IIIZZIIII,
#   40788.5 * IZZIIIIII,
#   40788.5 * ZIZIIIIII,
#   40788.5 * ZZIIIIIII,
#   40788.5 * IIIIIZIIZ,
#   40788.5 * IIZIIIIIZ,
#   40788.5 * IIZIIZIII,
#   40788.5 * IIIIZIIZI,
#   40788.5 * IZIIIIIZI,
#   40788.5 * IZIIZIIII,
#   40788.5 * IIIZIIZII,
#   40788.5 * ZIIIIIZII,
#   40788.5 * ZIIZIIIII
# ])
# -- quantum_instance: None
# -- optimizer: <qiskit.aqua.components.optimizers.spsa.SPSA object at 0x0000017CCFE1BE08>
# -- gradient: None
# -- cost_fn: <bound method VQE._energy_evaluation of <qiskit.aqua.algorithms.minimum_eigen_solvers.qaoa.qaoa.QAOA object at 0x0000017CCFEB30C8>>
# -- initial_point: [-1.68562361e+13 -5.55737246e+12 -3.08006492e+11 -3.77816806e+13
#   6.13419753e+12 -1.96283093e+12]
# -- var_form: <qiskit.aqua.algorithms.minimum_eigen_solvers.qaoa.var_form.QAOAVarForm object at 0x0000017CCFE59608>
# -- var_form_params: θ, ['θ[0]', 'θ[1]', 'θ[2]', 'θ[3]', 'θ[4]', 'θ[5]']
# -- parameterized_circuits: None
# -- ret: None
# -- eval_time: None
# -- callback: None
# -- aux_op_nones: []
# -- aux_operators: []
# -- eval_count: 0
# ===============================================================
# Variational Form: QAOAVarForm
# -- num_parameters: 6
# -- num_qubits: 9
# -- bounds: [(0, 3.141592653589793), (0, 3.141592653589793), (0, 3.141592653589793), (0, 6.283185307179586), (0, 6.283185307179586), (0, 6.283185307179586)]
# -- preferred_init_points: [0, 0, 0, 0, 0, 0]
# -- support_parameterized_circuit: True
# -- cost_operator: SummedOp([
#   588.0 * IIIIIZIZI,
#   -85173.0 * IIIIIIIZI,
#   -86572.5 * IIIIIZIII,
#   430.5 * IIIIIZZII,
#   -84303.0 * IIIIIIZII,
#   588.0 * IIIIZIIIZ,
#   -87203.0 * IIIIIIIIZ,
#   -84770.0 * IIIIZIIII,
#   63.0 * IIIIZIZII,
#   430.5 * IIIZIIIIZ,
#   -83997.5 * IIIZIIIII,
#   63.0 * IIIZIIIZI,
#   2660.0 * IIZIIIIZI,
#   -90161.5 * IIZIIIIII,
#   1947.5 * IIZIIIZII,
#   2660.0 * IZIIIIIIZ,
#   -87064.0 * IZIIIIIII,
#   285.0 * IZIIIIZII,
#   1947.5 * ZIIIIIIIZ,
#   -85736.5 * ZIIIIIIII,
#   285.0 * ZIIIIIIZI,
#   2296.0 * IIZIZIIII,
#   1681.0 * IIZZIIIII,
#   2296.0 * IZIIIZIII,
#   246.0 * IZIZIIIII,
#   1681.0 * ZIIIIZIII,
#   246.0 * ZIIIZIIII,
#   40788.5 * IIIIIIIZZ,
#   40788.5 * IIIIIIZIZ,
#   40788.5 * IIIIIIZZI,
#   40788.5 * IIIIZZIII,
#   40788.5 * IIIZIZIII,
#   40788.5 * IIIZZIIII,
#   40788.5 * IZZIIIIII,
#   40788.5 * ZIZIIIIII,
#   40788.5 * ZZIIIIIII,
#   40788.5 * IIIIIZIIZ,
#   40788.5 * IIZIIIIIZ,
#   40788.5 * IIZIIZIII,
#   40788.5 * IIIIZIIZI,
#   40788.5 * IZIIIIIZI,
#   40788.5 * IZIIZIIII,
#   40788.5 * IIIZIIZII,
#   40788.5 * ZIIIIIZII,
#   40788.5 * ZIIZIIIII
# ])
# -- p: 3
# -- initial_state: None
# -- mixer_operator: SummedOp([
#   XIIIIIIII,
#   IXIIIIIII,
#   IIXIIIIII,
#   IIIXIIIII,
#   IIIIXIIII,
#   IIIIIXIII,
#   IIIIIIXII,
#   IIIIIIIXI,
#   IIIIIIIIX
# ])
# ===============================================================
# Optimizer: SPSA
# -- gradient_support_level: 1
# -- bounds_support_level: 1
# -- initial_point_support_level: 3
# -- options: {'save_steps': 1, 'last_avg': 1}
# -- max_evals_grouped: 1
# -- maxiter: 1
# -- parameters: [0.62831853 0.1        0.602      0.101      0.        ]
# -- skip_calibration: False
# ===============================================================
#
# INFO:qiskit.aqua.algorithms.vq_algorithm:Starting optimizer.
# bounds=[(0, 3.141592653589793), (0, 3.141592653589793), (0, 3.141592653589793), (0, 6.283185307179586), (0, 6.283185307179586), (0, 6.283185307179586)]
# initial point=[-1.68562361e+13 -5.55737246e+12 -3.08006492e+11 -3.77816806e+13
#   6.13419753e+12 -1.96283093e+12]
# DEBUG:qiskit.aqua.components.optimizers.optimizer:WARNING: SPSA does not support bounds. It will be ignored.
# DEBUG:qiskit.aqua.components.optimizers.spsa:Parameters: [0.62831853 0.1        0.602      0.101      0.        ]
# DEBUG:qiskit.aqua.components.optimizers.spsa:Calibration...
# DEBUG:qiskit.aqua.components.optimizers.spsa:calibration step # 0 of 1
# \ This file has been generated by DOcplex
# \ ENCODING=ISO-8859-1
# \Problem name: qap3
#
# Minimize
#  obj: [ 4704 x_0_0*x_1_1 + 3444 x_0_0*x_1_2 + 21280 x_0_0*x_2_1
#       + 15580 x_0_0*x_2_2 + 4704 x_0_1*x_1_0 + 504 x_0_1*x_1_2
#       + 21280 x_0_1*x_2_0 + 2280 x_0_1*x_2_2 + 3444 x_0_2*x_1_0
#       + 504 x_0_2*x_1_1 + 15580 x_0_2*x_2_0 + 2280 x_0_2*x_2_1
#       + 18368 x_1_0*x_2_1 + 13448 x_1_0*x_2_2 + 18368 x_1_1*x_2_0
#       + 1968 x_1_1*x_2_2 + 13448 x_1_2*x_2_0 + 1968 x_1_2*x_2_1 ]/2
# Subject To
#  c1: x_0_0 + x_0_1 + x_0_2 = 1
#  c2: x_1_0 + x_1_1 + x_1_2 = 1
#  c3: x_2_0 + x_2_1 + x_2_2 = 1
#  c4: x_0_0 + x_1_0 + x_2_0 = 1
#  c5: x_0_1 + x_1_1 + x_2_1 = 1
#  c6: x_0_2 + x_1_2 + x_2_2 = 1
#
# Bounds
#  0 <= x_0_0 <= 1
#  0 <= x_0_1 <= 1
#  0 <= x_0_2 <= 1
#  0 <= x_1_0 <= 1
#  0 <= x_1_1 <= 1
#  0 <= x_1_2 <= 1
#  0 <= x_2_0 <= 1
#  0 <= x_2_1 <= 1
#  0 <= x_2_2 <= 1
#
# Binaries
#  x_0_0 x_0_1 x_0_2 x_1_0 x_1_1 x_1_2 x_2_0 x_2_1 x_2_2
# End
# INFO:qiskit.transpiler.runningpassmanager:Pass: SetLayout - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: TrivialLayout - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Layout2qDistance - 4.99916 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: DenseLayout - 29.98114 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FullAncillaAllocation - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: EnlargeWithAncilla - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: ApplyLayout - 19.00268 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Unroll3qOrMore - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CheckMap - 1.00136 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: BarrierBeforeFinalMeasurements - 4.99868 (ms)
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:StochasticSwap default_rng seeded with seed=10598
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:schedule:
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    0: [[Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 12)], [Qubit(QuantumRegister(20, 'q'), 10)], [Qubit(QuantumRegister(20, 'q'), 11)], [Qubit(QuantumRegister(20, 'q'), 16)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    1: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    2: [[Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    3: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    4: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 7)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    5: [[Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 7)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    6: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 7)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    7: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 11)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    8: [[Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 11)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    9: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 11)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    10: [[Qubit(QuantumRegister(20, 'q'), 7), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    11: [[Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    12: [[Qubit(QuantumRegister(20, 'q'), 7), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    13: [[Qubit(QuantumRegister(20, 'q'), 7), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    14: [[Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    15: [[Qubit(QuantumRegister(20, 'q'), 7), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    16: [[Qubit(QuantumRegister(20, 'q'), 6), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    17: [[Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    18: [[Qubit(QuantumRegister(20, 'q'), 6), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    19: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 12)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 5)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    20: [[Qubit(QuantumRegister(20, 'q'), 12)], [Qubit(QuantumRegister(20, 'q'), 5)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    21: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 12)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 5)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    22: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 13)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    23: [[Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 13)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    24: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 13)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    25: [[Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    26: [[Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    27: [[Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    28: [[Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 16)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    29: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    30: [[Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    31: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 11)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    32: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 16)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    33: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    34: [[Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 10)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    35: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 11)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    36: [[Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    37: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    38: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    39: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    40: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    41: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    42: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    43: [[Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    44: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    45: [[Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    46: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    47: [[Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    48: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    49: [[Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 7)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    50: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 7)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    51: [[Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 7)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    52: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 7)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    53: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 7)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    54: [[Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 7)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    55: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    56: [[Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 11)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    57: [[Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 11)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    58: [[Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 11)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    59: [[Qubit(QuantumRegister(20, 'q'), 7), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    60: [[Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    61: [[Qubit(QuantumRegister(20, 'q'), 7), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    62: [[Qubit(QuantumRegister(20, 'q'), 7), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    63: [[Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    64: [[Qubit(QuantumRegister(20, 'q'), 7), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    65: [[Qubit(QuantumRegister(20, 'q'), 6), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    66: [[Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    67: [[Qubit(QuantumRegister(20, 'q'), 6), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    68: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 12)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 5)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    69: [[Qubit(QuantumRegister(20, 'q'), 12)], [Qubit(QuantumRegister(20, 'q'), 5)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    70: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 12)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 5)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    71: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 13)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    72: [[Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 13)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    73: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 13)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    74: [[Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    75: [[Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    76: [[Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    77: [[Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 16)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    78: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    79: [[Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    80: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 11)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    81: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 16)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    82: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    83: [[Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 10)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    84: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 11)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    85: [[Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    86: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    87: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    88: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    89: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    90: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    91: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    92: [[Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    93: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    94: [[Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    95: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    96: [[Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    97: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    98: [[Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 7)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    99: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 7)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    100: [[Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 7)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    101: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 7)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    102: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 7)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    103: [[Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 7)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    104: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    105: [[Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 11)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    106: [[Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 11)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    107: [[Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 11)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    108: [[Qubit(QuantumRegister(20, 'q'), 7), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    109: [[Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    110: [[Qubit(QuantumRegister(20, 'q'), 7), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    111: [[Qubit(QuantumRegister(20, 'q'), 7), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    112: [[Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    113: [[Qubit(QuantumRegister(20, 'q'), 7), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    114: [[Qubit(QuantumRegister(20, 'q'), 6), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    115: [[Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    116: [[Qubit(QuantumRegister(20, 'q'), 6), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    117: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 12)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 5)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    118: [[Qubit(QuantumRegister(20, 'q'), 12)], [Qubit(QuantumRegister(20, 'q'), 5)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    119: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 12)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 5)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    120: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 13)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    121: [[Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 13)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    122: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 13)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    123: [[Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    124: [[Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    125: [[Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    126: [[Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 16)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    127: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    128: [[Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    129: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 11)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    130: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 16)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    131: [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    132: [[Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 10)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    133: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 11)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    134: [[Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    135: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    136: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 10)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    137: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    138: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 6)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    139: [[Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    140: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    141: [[Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    142: [[Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    143: [[Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    144: [[Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    145: [[Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    146: [[Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 1)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    147: [[Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 5)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    148: []
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:    149: [[Qubit(QuantumRegister(20, 'q'), 11)], [Qubit(QuantumRegister(20, 'q'), 10)], [Qubit(QuantumRegister(20, 'q'), 12)], [Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 16)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:trivial_layout = Layout({
# 0: Qubit(QuantumRegister(20, 'q'), 0),
# 1: Qubit(QuantumRegister(20, 'q'), 1),
# 2: Qubit(QuantumRegister(20, 'q'), 2),
# 3: Qubit(QuantumRegister(20, 'q'), 3),
# 4: Qubit(QuantumRegister(20, 'q'), 4),
# 5: Qubit(QuantumRegister(20, 'q'), 5),
# 6: Qubit(QuantumRegister(20, 'q'), 6),
# 7: Qubit(QuantumRegister(20, 'q'), 7),
# 8: Qubit(QuantumRegister(20, 'q'), 8),
# 9: Qubit(QuantumRegister(20, 'q'), 9),
# 10: Qubit(QuantumRegister(20, 'q'), 10),
# 11: Qubit(QuantumRegister(20, 'q'), 11),
# 12: Qubit(QuantumRegister(20, 'q'), 12),
# 13: Qubit(QuantumRegister(20, 'q'), 13),
# 14: Qubit(QuantumRegister(20, 'q'), 14),
# 15: Qubit(QuantumRegister(20, 'q'), 15),
# 16: Qubit(QuantumRegister(20, 'q'), 16),
# 17: Qubit(QuantumRegister(20, 'q'), 17),
# 18: Qubit(QuantumRegister(20, 'q'), 18),
# 19: Qubit(QuantumRegister(20, 'q'), 19)
# })
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: layer_partition = [[Qubit(QuantumRegister(20, 'q'), 1)], [Qubit(QuantumRegister(20, 'q'), 6)], [Qubit(QuantumRegister(20, 'q'), 7)], [Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 12)], [Qubit(QuantumRegister(20, 'q'), 10)], [Qubit(QuantumRegister(20, 'q'), 11)], [Qubit(QuantumRegister(20, 'q'), 16)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: layout = {Qubit(QuantumRegister(20, 'q'), 0): 0, Qubit(QuantumRegister(20, 'q'), 1): 1, Qubit(QuantumRegister(20, 'q'), 2): 2, Qubit(QuantumRegister(20, 'q'), 3): 3, Qubit(QuantumRegister(20, 'q'), 4): 4, Qubit(QuantumRegister(20, 'q'), 5): 5, Qubit(QuantumRegister(20, 'q'), 6): 6, Qubit(QuantumRegister(20, 'q'), 7): 7, Qubit(QuantumRegister(20, 'q'), 8): 8, Qubit(QuantumRegister(20, 'q'), 9): 9, Qubit(QuantumRegister(20, 'q'), 10): 10, Qubit(QuantumRegister(20, 'q'), 11): 11, Qubit(QuantumRegister(20, 'q'), 12): 12, Qubit(QuantumRegister(20, 'q'), 13): 13, Qubit(QuantumRegister(20, 'q'), 14): 14, Qubit(QuantumRegister(20, 'q'), 15): 15, Qubit(QuantumRegister(20, 'q'), 16): 16, Qubit(QuantumRegister(20, 'q'), 17): 17, Qubit(QuantumRegister(20, 'q'), 18): 18, Qubit(QuantumRegister(20, 'q'), 19): 19}
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: qubit_subset = dict_keys([Qubit(QuantumRegister(20, 'q'), 0), Qubit(QuantumRegister(20, 'q'), 1), Qubit(QuantumRegister(20, 'q'), 2), Qubit(QuantumRegister(20, 'q'), 3), Qubit(QuantumRegister(20, 'q'), 4), Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 6), Qubit(QuantumRegister(20, 'q'), 7), Qubit(QuantumRegister(20, 'q'), 8), Qubit(QuantumRegister(20, 'q'), 9), Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 14), Qubit(QuantumRegister(20, 'q'), 15), Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 17), Qubit(QuantumRegister(20, 'q'), 18), Qubit(QuantumRegister(20, 'q'), 19)])
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: trials = 20
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: gates = []
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: distance = 0
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: nothing to do
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:mapper: layer 0
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:mapper: success_flag=True,best_depth=0
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_update: layout = Layout({
# 0: Qubit(QuantumRegister(20, 'q'), 0),
# 1: Qubit(QuantumRegister(20, 'q'), 1),
# 2: Qubit(QuantumRegister(20, 'q'), 2),
# 3: Qubit(QuantumRegister(20, 'q'), 3),
# 4: Qubit(QuantumRegister(20, 'q'), 4),
# 5: Qubit(QuantumRegister(20, 'q'), 5),
# 6: Qubit(QuantumRegister(20, 'q'), 6),
# 7: Qubit(QuantumRegister(20, 'q'), 7),
# 8: Qubit(QuantumRegister(20, 'q'), 8),
# 9: Qubit(QuantumRegister(20, 'q'), 9),
# 10: Qubit(QuantumRegister(20, 'q'), 10),
# 11: Qubit(QuantumRegister(20, 'q'), 11),
# 12: Qubit(QuantumRegister(20, 'q'), 12),
# 13: Qubit(QuantumRegister(20, 'q'), 13),
# 14: Qubit(QuantumRegister(20, 'q'), 14),
# 15: Qubit(QuantumRegister(20, 'q'), 15),
# 16: Qubit(QuantumRegister(20, 'q'), 16),
# 17: Qubit(QuantumRegister(20, 'q'), 17),
# 18: Qubit(QuantumRegister(20, 'q'), 18),
# 19: Qubit(QuantumRegister(20, 'q'), 19)
# })
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_update: self.trivial_layout = Layout({
# 0: Qubit(QuantumRegister(20, 'q'), 0),
# 1: Qubit(QuantumRegister(20, 'q'), 1),
# 2: Qubit(QuantumRegister(20, 'q'), 2),
# 3: Qubit(QuantumRegister(20, 'q'), 3),
# 4: Qubit(QuantumRegister(20, 'q'), 4),
# 5: Qubit(QuantumRegister(20, 'q'), 5),
# 6: Qubit(QuantumRegister(20, 'q'), 6),
# 7: Qubit(QuantumRegister(20, 'q'), 7),
# 8: Qubit(QuantumRegister(20, 'q'), 8),
# 9: Qubit(QuantumRegister(20, 'q'), 9),
# 10: Qubit(QuantumRegister(20, 'q'), 10),
# 11: Qubit(QuantumRegister(20, 'q'), 11),
# 12: Qubit(QuantumRegister(20, 'q'), 12),
# 13: Qubit(QuantumRegister(20, 'q'), 13),
# 14: Qubit(QuantumRegister(20, 'q'), 14),
# 15: Qubit(QuantumRegister(20, 'q'), 15),
# 16: Qubit(QuantumRegister(20, 'q'), 16),
# 17: Qubit(QuantumRegister(20, 'q'), 17),
# 18: Qubit(QuantumRegister(20, 'q'), 18),
# 19: Qubit(QuantumRegister(20, 'q'), 19)
# })
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_update: there are no swaps in this layer
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: layer_partition = [[Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 13)], [Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 5)], [Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 12)]]
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: layout = {Qubit(QuantumRegister(20, 'q'), 0): 0, Qubit(QuantumRegister(20, 'q'), 1): 1, Qubit(QuantumRegister(20, 'q'), 2): 2, Qubit(QuantumRegister(20, 'q'), 3): 3, Qubit(QuantumRegister(20, 'q'), 4): 4, Qubit(QuantumRegister(20, 'q'), 5): 5, Qubit(QuantumRegister(20, 'q'), 6): 6, Qubit(QuantumRegister(20, 'q'), 7): 7, Qubit(QuantumRegister(20, 'q'), 8): 8, Qubit(QuantumRegister(20, 'q'), 9): 9, Qubit(QuantumRegister(20, 'q'), 10): 10, Qubit(QuantumRegister(20, 'q'), 11): 11, Qubit(QuantumRegister(20, 'q'), 12): 12, Qubit(QuantumRegister(20, 'q'), 13): 13, Qubit(QuantumRegister(20, 'q'), 14): 14, Qubit(QuantumRegister(20, 'q'), 15): 15, Qubit(QuantumRegister(20, 'q'), 16): 16, Qubit(QuantumRegister(20, 'q'), 17): 17, Qubit(QuantumRegister(20, 'q'), 18): 18, Qubit(QuantumRegister(20, 'q'), 19): 19}
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: qubit_subset = dict_keys([Qubit(QuantumRegister(20, 'q'), 0), Qubit(QuantumRegister(20, 'q'), 1), Qubit(QuantumRegister(20, 'q'), 2), Qubit(QuantumRegister(20, 'q'), 3), Qubit(QuantumRegister(20, 'q'), 4), Qubit(QuantumRegister(20, 'q'), 5), Qubit(QuantumRegister(20, 'q'), 6), Qubit(QuantumRegister(20, 'q'), 7), Qubit(QuantumRegister(20, 'q'), 8), Qubit(QuantumRegister(20, 'q'), 9), Qubit(QuantumRegister(20, 'q'), 10), Qubit(QuantumRegister(20, 'q'), 11), Qubit(QuantumRegister(20, 'q'), 12), Qubit(QuantumRegister(20, 'q'), 13), Qubit(QuantumRegister(20, 'q'), 14), Qubit(QuantumRegister(20, 'q'), 15), Qubit(QuantumRegister(20, 'q'), 16), Qubit(QuantumRegister(20, 'q'), 17), Qubit(QuantumRegister(20, 'q'), 18), Qubit(QuantumRegister(20, 'q'), 19)])
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:layer_permutation: trials = 20
# ...
# 6: Qubit(QuantumRegister(20, 'q'), 6),
# 7: Qubit(QuantumRegister(20, 'q'), 7),
# 8: Qubit(QuantumRegister(20, 'q'), 8),
# 9: Qubit(QuantumRegister(20, 'q'), 9),
# 10: Qubit(QuantumRegister(20, 'q'), 10),
# 11: Qubit(QuantumRegister(20, 'q'), 11),
# 12: Qubit(QuantumRegister(20, 'q'), 12),
# 13: Qubit(QuantumRegister(20, 'q'), 13),
# 14: Qubit(QuantumRegister(20, 'q'), 14),
# 15: Qubit(QuantumRegister(20, 'q'), 15),
# 16: Qubit(QuantumRegister(20, 'q'), 16),
# 17: Qubit(QuantumRegister(20, 'q'), 17),
# 18: Qubit(QuantumRegister(20, 'q'), 18),
# 19: Qubit(QuantumRegister(20, 'q'), 19)
# })
# DEBUG:qiskit.transpiler.passes.routing.stochastic_swap:mapper: layout = Layout({
# 0: Qubit(QuantumRegister(20, 'q'), 0),
# 11: Qubit(QuantumRegister(20, 'q'), 1),
# 2: Qubit(QuantumRegister(20, 'q'), 2),
# 3: Qubit(QuantumRegister(20, 'q'), 3),
# 4: Qubit(QuantumRegister(20, 'q'), 4),
# 16: Qubit(QuantumRegister(20, 'q'), 5),
# 13: Qubit(QuantumRegister(20, 'q'), 6),
# 17: Qubit(QuantumRegister(20, 'q'), 7),
# 8: Qubit(QuantumRegister(20, 'q'), 8),
# 9: Qubit(QuantumRegister(20, 'q'), 9),
# 7: Qubit(QuantumRegister(20, 'q'), 10),
# 10: Qubit(QuantumRegister(20, 'q'), 11),
# 12: Qubit(QuantumRegister(20, 'q'), 12),
# 18: Qubit(QuantumRegister(20, 'q'), 13),
# 14: Qubit(QuantumRegister(20, 'q'), 14),
# 15: Qubit(QuantumRegister(20, 'q'), 15),
# 5: Qubit(QuantumRegister(20, 'q'), 16),
# 1: Qubit(QuantumRegister(20, 'q'), 17),
# 6: Qubit(QuantumRegister(20, 'q'), 18),
# 19: Qubit(QuantumRegister(20, 'q'), 19)
# })
# INFO:qiskit.transpiler.runningpassmanager:Pass: StochasticSwap - 8273.53692 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: UnrollCustomDefinitions - 3.99780 (ms)
# INFO:qiskit.transpiler.passes.basis.basis_translator:Begin BasisTranslator from source basis {('cx', 2), ('rz', 1), ('h', 1), ('rx', 1), ('barrier', 20), ('measure', 1), ('swap', 2)} to target basis {'u2', 'cx', 'delay', 'u1', 'id', 'reset', 'measure', 'snapshot', 'u3', 'barrier'}.
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Begining basis search from frozenset({('barrier', 20), ('cx', 2), ('rz', 1), ('measure', 1), ('h', 1), ('swap', 2), ('rx', 1)}) to frozenset({'u2', 'cx', 'snapshot', 'delay', 'u1', 'u3', 'id', 'reset', 'barrier', 'measure'}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('barrier', 20), ('cx', 2), ('rz', 1), ('measure', 1), ('h', 1), ('swap', 2), ('rx', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('barrier', 20), ('cx', 2), ('measure', 1), ('h', 1), ('u1', 1), ('swap', 2), ('rx', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('barrier', 20), ('cx', 2), ('measure', 1), ('u1', 1), ('swap', 2), ('u2', 1), ('rx', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('barrier', 20), ('cx', 2), ('measure', 1), ('u1', 1), ('u2', 1), ('rx', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('barrier', 20), ('cx', 2), ('u3', 1), ('measure', 1), ('u2', 1), ('rx', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('barrier', 20), ('cx', 2), ('u3', 1), ('measure', 1), ('u1', 1), ('rx', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Inspecting basis frozenset({('barrier', 20), ('cx', 2), ('measure', 1), ('u1', 1), ('r', 1), ('u2', 1)}).
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Transformation path:
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:rz/1 => [Parameter(theta)]
# global phase: -0.5*theta
#      ┌───────────┐
# q_0: ┤ U1(theta) ├
#      └───────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:h/1 => []
#      ┌─────────┐
# q_0: ┤ U2(0,π) ├
#      └─────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:swap/2 => []
#           ┌───┐
# q_0: ──■──┤ X ├──■──
#      ┌─┴─┐└─┬─┘┌─┴─┐
# q_1: ┤ X ├──■──┤ X ├
#      └───┘     └───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:rx/1 => [Parameter(theta)]
#      ┌────────────┐
# q_0: ┤ R(theta,0) ├
#      └────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:r/1 => [Parameter(theta), Parameter(phi)]
#      ┌───────────────────────────────────────────────────────────┐
# q_0: ┤ U3(theta,phi - 1.5707963267949,1.5707963267949 - 1.0*phi) ├
#      └───────────────────────────────────────────────────────────┘
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation path search completed in 0.061s.
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: rz/1 [Parameter(theta)] =>
# global phase: -0.5*theta
#      ┌───────────┐
# q_0: ┤ U1(theta) ├
#      └───────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('rz', 1) rz, ['rz[0]'] from
#       ┌───────────┐
# q1_0: ┤ rz(rz[0]) ├
#       └───────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('rz', 1) rz, ['rz[0]'] to
# global phase: -0.5*rz[0]
#       ┌───────────┐
# q1_0: ┤ U1(rz[0]) ├
#       └───────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: h/1 [] =>
#      ┌─────────┐
# q_0: ┤ U2(0,π) ├
#      └─────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('h', 1) h, [] from
#       ┌───┐
# q2_0: ┤ h ├
#       └───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('h', 1) h, [] to
#       ┌─────────┐
# q2_0: ┤ U2(0,π) ├
#       └─────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: swap/2 [] =>
#           ┌───┐
# q_0: ──■──┤ X ├──■──
#      ┌─┴─┐└─┬─┘┌─┴─┐
# q_1: ┤ X ├──■──┤ X ├
#      └───┘     └───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('swap', 2) swap, [] from
#       ┌───────┐
# q6_0: ┤0      ├
#       │  swap │
# q6_1: ┤1      ├
#       └───────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('swap', 2) swap, [] to
#            ┌───┐
# q6_0: ──■──┤ X ├──■──
#       ┌─┴─┐└─┬─┘┌─┴─┐
# q6_1: ┤ X ├──■──┤ X ├
#       └───┘     └───┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: rx/1 [Parameter(theta)] =>
#      ┌────────────┐
# q_0: ┤ R(theta,0) ├
#      └────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('rx', 1) rx, ['rx[0]'] from
#       ┌───────────┐
# q3_0: ┤ rx(rx[0]) ├
#       └───────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('rx', 1) rx, ['rx[0]'] to
#       ┌────────────┐
# q3_0: ┤ R(rx[0],0) ├
#       └────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Composing transform step: r/1 [Parameter(theta), Parameter(phi)] =>
#      ┌───────────────────────────────────────────────────────────┐
# q_0: ┤ U3(theta,phi - 1.5707963267949,1.5707963267949 - 1.0*phi) ├
#      └───────────────────────────────────────────────────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updating transform for mapped instr ('rx', 1) rx, ['rx[0]'] from
#       ┌────────────┐
# q3_0: ┤ R(rx[0],0) ├
#       └────────────┘
# DEBUG:qiskit.transpiler.passes.basis.basis_translator:Updated transform for mapped instr ('rx', 1) rx, ['rx[0]'] to
#       ┌────────────────────┐
# q3_0: ┤ U3(rx[0],-π/2,π/2) ├
#       └────────────────────┘
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation paths composed in 0.071s.
# INFO:qiskit.transpiler.passes.basis.basis_translator:Basis translation instructions replaced in 0.401s.
# INFO:qiskit.transpiler.runningpassmanager:Pass: BasisTranslator - 540.27247 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: RemoveResetInZeroState - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 4.99821 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CXCancellation - 4.99725 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 6.99687 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CXCancellation - 3.99470 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Depth - 0.99754 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: FixedPoint - 0.00000 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: Optimize1qGates - 8.99601 (ms)
# INFO:qiskit.transpiler.runningpassmanager:Pass: CXCancellation - 7.99251 (ms)
# INFO:qiskit.compiler.transpile:Total Transpile Time - 9713.13524 (ms)
# DEBUG:qiskit.aqua.quantum_instance:==== Before transpiler ====
# DEBUG:qiskit.aqua.quantum_instance:Submitting 1 circuits.
# ============================================================================
# 0-th circuit: 9 qubits, 9 classical bits and 396 operations with depth 149
# op_counts: OrderedDict([('cx', 216), ('rz', 135), ('rx', 27), ('h', 9), ('measure', 9)])
# ============================================================================
#
# DEBUG:qiskit.aqua.quantum_instance:====  After transpiler ====
# DEBUG:qiskit.aqua.quantum_instance:Submitting 1 circuits.
# ============================================================================
# 0-th circuit: 20 qubits, 9 classical bits and 917 operations with depth 366
# op_counts: OrderedDict([('cx', 737), ('u1', 135), ('u3', 27), ('u2', 9), ('measure', 9), ('barrier', 1)])
# ============================================================================
#
# DEBUG:qiskit.aqua.operators.converters.circuit_sampler:Parameter binding 127.92754 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.compiler.assemble:Total Assembly Time - 0.00000 (ms)
# INFO:qiskit.aqua.utils.run_circuits:Backend status: <qiskit.providers.models.backendstatus.BackendStatus object at 0x0000017CD0558F08>
# INFO:qiskit.aqua.utils.run_circuits:There are 1 jobs are submitted.
# INFO:qiskit.aqua.utils.run_circuits:All job ids:
# ['3590e68a-e1a4-4ac3-8c7e-d1e00bc8994b']
# INFO:qiskit.aqua.utils.run_circuits:Running 0-th qobj, job id: 3590e68a-e1a4-4ac3-8c7e-d1e00bc8994b
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-11-b7893c640623> in <module>
#       7 backend = 'ifake_boeb'
#       8 optimal_point = read_optimal(ins)
# ----> 9 ans = testing_quantum(ins, iterations, backend, optimal_point, 21)
#
# <ipython-input-9-8ef467141f78> in testing_quantum(ins, iterations, backend, optimal_point, trials)
#      56
#      57         qaoa = QAOA(qubitOp_docplex,optimizer=spsa, p=3,include_custom=True,initial_point = optimal_point)
# ---> 58         result = qaoa.run(quantum_instance)
#      59         print(result['optimal_point'])
#      60         #print('QAOA vector:', result['eigenstate'])
#
# ~\Anaconda3\lib\site-packages\qiskit\aqua\algorithms\quantum_algorithm.py in run(self, quantum_instance, **kwargs)
#      69                 self.quantum_instance = quantum_instance
#      70
# ---> 71         return self._run()
#      72
#      73     @abstractmethod
#
# ~\Anaconda3\lib\site-packages\qiskit\aqua\algorithms\minimum_eigen_solvers\vqe.py in _run(self)
#     431                                      cost_fn=self._energy_evaluation,
#     432                                      gradient_fn=self._gradient,
# --> 433                                      optimizer=self.optimizer)
#     434
#     435         # TODO remove all former dictionary logic
#
# ~\Anaconda3\lib\site-packages\qiskit\aqua\algorithms\vq_algorithm.py in find_minimum(self, initial_point, var_form, cost_fn, optimizer, gradient_fn)
#     211                                                                       variable_bounds=bounds,
#     212                                                                       initial_point=initial_point,
# --> 213                                                                       gradient_function=gradient_fn)
#     214         eval_time = time.time() - start
#     215
#
# ~\Anaconda3\lib\site-packages\qiskit\aqua\components\optimizers\spsa.py in optimize(self, num_vars, objective_function, gradient_function, variable_bounds, initial_point)
#     123             # at least one calibration, at most 25 calibrations
#     124             num_steps_calibration = min(25, max(1, self._maxiter // 5))
# --> 125             self._calibration(objective_function, initial_point, num_steps_calibration)
#     126         else:
#     127             logger.debug('Skipping calibration, parameters used as provided.')
#
# ~\Anaconda3\lib\site-packages\qiskit\aqua\components\optimizers\spsa.py in _calibration(self, obj_fun, initial_theta, stat)
#     241                 obj_plus, obj_minus = obj_fun(np.concatenate((theta_plus, theta_minus)))
#     242             else:
# --> 243                 obj_plus = obj_fun(theta_plus)
#     244                 obj_minus = obj_fun(theta_minus)
#     245             delta_obj += np.absolute(obj_plus - obj_minus) / stat
#
# ~\Anaconda3\lib\site-packages\qiskit\aqua\algorithms\minimum_eigen_solvers\vqe.py in _energy_evaluation(self, parameters)
#     523
#     524         start_time = time()
# --> 525         sampled_expect_op = self._circuit_sampler.convert(self._expect_op, params=param_bindings)
#     526         means = np.real(sampled_expect_op.eval())
#     527
#
# ~\Anaconda3\lib\site-packages\qiskit\aqua\operators\converters\circuit_sampler.py in convert(self, operator, params)
#     204         p_b = cast(List[Dict[Parameter, List[float]]], param_bindings)
#     205         sampled_statefn_dicts = self.sample_circuits(circuit_sfns=circs,
# --> 206                                                      param_bindings=p_b)
#     207
#     208         def replace_circuits_with_dicts(operator, param_index=0):
#
# ~\Anaconda3\lib\site-packages\qiskit\aqua\operators\converters\circuit_sampler.py in sample_circuits(self, circuit_sfns, param_bindings)
#     291
#     292         results = self.quantum_instance.execute(ready_circs,
# --> 293                                                 had_transpiled=self._transpile_before_bind)
#     294
#     295         if param_bindings is not None and self._param_qobj:
#
# ~\Anaconda3\lib\site-packages\qiskit\aqua\quantum_instance.py in execute(self, circuits, had_transpiled)
#     398             result = run_qobj(qobj, self._backend, self._qjob_config,
#     399                               self._backend_options, self._noise_config,
# --> 400                               self._skip_qobj_validation, self._job_callback)
#     401
#     402         if self._circuit_summary:
#
# ~\Anaconda3\lib\site-packages\qiskit\aqua\utils\run_circuits.py in run_qobj(qobj, backend, qjob_config, backend_options, noise_config, skip_qobj_validation, job_callback)
#     282                 if job_status == JobStatus.DONE:
#     283                     while True:
# --> 284                         result = job.result(**qjob_config)
#     285                         if result.success:
#     286                             results.append(result)
#
# ~\Anaconda3\lib\site-packages\qiskit\providers\aer\aerjob.py in _wrapper(self, *args, **kwargs)
#      40         if self._future is None:
#      41             raise JobError("Job not submitted yet!. You have to .submit() first!")
# ---> 42         return func(self, *args, **kwargs)
#      43     return _wrapper
#      44
#
# TypeError: result() got an unexpected keyword argument 'wait'

# %%
ins = "made4.csv"
iterations = 50
import logging
logging.basicConfig(level=logging.DEBUG) # log the steps of the algorithm and results
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
backend ='ibmq_sydney'
optimal_point = read_optimal(ins)
ans = testing_quantum(ins, iterations, backend, optimal_point, 30)

# %%
ins = "made5.csv"
iterations = 
import logging
logging.basicConfig(level=logging.DEBUG) # log the steps of the algorithm and results
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
backend ='ibmq_sydney'
optimal_point = read_optimal(ins)
ans = testing_quantum(ins, iterations, backend, optimal_point, 30)

# %%
qiskit.__qiskit_version__
